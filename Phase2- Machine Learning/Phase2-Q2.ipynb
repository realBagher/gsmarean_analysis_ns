# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import tqdm
pd.set_option('display.max_column', None)
pd.set_option('display.max_row', None)
from sklearn.ensemble import IsolationForest

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTENC

# %%
data = pd.read_csv(r"gsmarean_analysis_ns\data-phase2.csv", index_col=0)

# %%
data.shape
# Out:
# (2651, 36)

# %%
data.head()
# Out:
#                     name    brand    2G    3G    4G     5G  Announced  \
# 0      alcatel 1b (2022)  alcatel  True  True  True  False     2022.0
# 1  alcatel 1l pro (2021)  alcatel  True  True  True  False     2021.0
# 2       alcatel 1 (2021)  alcatel  True  True  True  False     2021.0
# 3      alcatel 3l (2021)  alcatel  True  True  True  False     2021.0
# 4      alcatel 1s (2021)  alcatel  True  True  True  False     2021.0
#
#       Status  Weight  Length   Width Diameter       SIM Display Type  \
# 0  Available   172.0  146.7    71.9       10   Nano-SIM      TFT LCD
# 1  Available   190.0  156.4    74.8      9.7   Nano-SIM      IPS LCD
# 2  Available   134.0  137.6    65.7      9.8   Nano-SIM      TFT LCD
# 3  Available   194.0  165.6    75.6      8.7   Nano-SIM      IPS LCD
# 4  Available   190.0  165.6    75.6      8.8   Nano-SIM      IPS LCD
#
#    Display Size    ppi  body ratio          OS  battery_capacity  Price  CPU  \
# 0          5.50  293.0        74.0  Android 11            3000.0  100.0  4.0
# 1          6.10  282.0        78.1  Android 11            3000.0  110.0  8.0
# 2          5.00  215.0        71.4  Android 11            2000.0   60.0  4.0
# 3          6.52  269.0        82.0  Android 11            4000.0  330.0  8.0
# 4          6.52  269.0        82.0  Android 11            4000.0  130.0  8.0
#
#   ratio      pixel                              WLAN  \
# 0  18:9  1036800.0  Wi-Fi 802.11 b/g/n, Wi-Fi Direct
# 1   5:9  1123200.0  Wi-Fi 802.11 b/g/n, Wi-Fi Direct
# 2  18:9   460800.0  Wi-Fi 802.11 b/g/n, Wi-Fi Direct
# 3  20:9  1152000.0  Wi-Fi 802.11 b/g/n, Wi-Fi Direct
# 4  20:9  1152000.0  Wi-Fi 802.11 b/g/n, Wi-Fi Direct
#
#                          Colors  \
# 0    Prime Black, Atlantic Blue
# 1     Power Grey, Twilight Blue
# 2        Volcano Black, AI Aqua
# 3   Jewelry Blue, Jewelry Black
# 4  Elegant Black, Twilight Blue
#
#                                              Sensors      Bluetooth  \
# 0                                      Accelerometer      5.0, A2DP
# 1  Fingerprint (rear-mounted), accelerometer, pro...      4.2, A2DP
# 2                           Accelerometer, proximity  4.2, A2DP, LE
# 3  Fingerprint (rear-mounted), accelerometer, pro...  5.0, A2DP, LE
# 4  Fingerprint (rear-mounted), accelerometer, pro...  5.0, A2DP, LE
#
#               GPU  Loudspeaker  3.5mm jack  \
# 0  PowerVR GE8300         True        True
# 1         IMG8322         True        True
# 2  PowerVR GE8100         True        True
# 3  PowerVR GE8320         True        True
# 4  PowerVR GE8320         True        True
#
#                               Chipset  \
# 0   Mediatek MT6761 Helio A22 (12 nm)
# 1               Unisoc SC9863A (28nm)
# 2             Mediatek MT6739 (28 nm)
# 3  Mediatek MT6762D Helio P22 (12 nm)
# 4  Mediatek MT6762D Helio P22 (12 nm)
#
#                                              Network  \
# 0  GSM / HSPA / LTE HSPA 42.2/11.1 Mbps, LTE Cat4...
# 1  GSM / HSPA / LTE HSPA 21.1/5.76 Mbps, LTE Cat4...
# 2  GSM / HSPA / LTE HSPA 42.2/11.5 Mbps, LTE Cat4...
# 3  GSM / HSPA / LTE HSPA 42.2/5.76 Mbps, LTE Cat4...
# 4  GSM / HSPA / LTE HSPA 42.2/5.76 Mbps, LTE Cat4...
#
#                     Internal                          Card slot  RAM  Storage
# 0               32GB 2GB RAM         microSDXC (dedicated slot)  2.0     32.0
# 1               32GB 2GB RAM   microSDXC (uses shared SIM slot)  2.0     32.0
# 2  8GB 1GB RAM, 16GB 1GB RAM         microSDHC (dedicated slot)  1.0      8.0
# 3               64GB 4GB RAM  microSDXC (only single sim model)  4.0     64.0
# 4               32GB 3GB RAM   microSDXC (uses shared SIM slot)  3.0     32.0

# %% [markdown]
# ### Pre-Processing... & Feature Engineering

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2651 entries, 0 to 4678
# Data columns (total 36 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              2651 non-null   object
#  1   brand             2651 non-null   object
#  2   2G                2651 non-null   bool
#  3   3G                2651 non-null   bool
#  4   4G                2651 non-null   bool
#  5   5G                2651 non-null   bool
#  6   Announced         2651 non-null   float64
#  7   Status            2651 non-null   object
#  8   Weight            2651 non-null   float64
#  9   Length            2651 non-null   object
#  10  Width             2651 non-null   object
#  11  Diameter          2651 non-null   object
#  12  SIM               2651 non-null   object
#  13  Display Type      2651 non-null   object
#  14  Display Size      2651 non-null   float64
#  15  ppi               2651 non-null   float64
#  16  body ratio        2651 non-null   float64
#  17  OS                2651 non-null   object
#  18  battery_capacity  2651 non-null   float64
#  19  Price             2651 non-null   float64
#  20  CPU               2372 non-null   float64
#  21  ratio             2651 non-null   object
#  22  pixel             2651 non-null   float64
#  23  WLAN              2650 non-null   object
#  24  Colors            2650 non-null   object
#  25  Sensors           2632 non-null   object
#  26  Bluetooth         2651 non-null   object
#  27  GPU               2427 non-null   object
#  28  Loudspeaker       2651 non-null   bool
#  29  3.5mm jack        2651 non-null   bool
#  30  Chipset           2394 non-null   object
#  31  Network           2651 non-null   object
#  32  Internal          2651 non-null   object
#  33  Card slot         2651 non-null   object
#  34  RAM               2651 non-null   float64
#  35  Storage           2651 non-null   float64
# dtypes: bool(6), float64(11), object(19)
# memory usage: 657.6+ KB

# %%
data.columns.values
# Out:
# array(['name', 'brand', '2G', '3G', '4G', '5G', 'Announced', 'Status',
#        'Weight', 'Length', 'Width', 'Diameter', 'SIM', 'Display Type',
#        'Display Size', 'ppi', 'body ratio', 'OS', 'battery_capacity',
#        'Price', 'CPU', 'ratio', 'pixel', 'WLAN', 'Colors', 'Sensors',
#        'Bluetooth', 'GPU', 'Loudspeaker', '3.5mm jack', 'Chipset',
#        'Network', 'Internal', 'Card slot', 'RAM', 'Storage'], dtype=object)

# %%
data['2G'].value_counts()
# Out:
# 2G
# True    2651
# Name: count, dtype: int64

# %%
data['Status'].value_counts()
# Out:
# Status
# Discontinued    1381
# Available       1267
# Coming             3
# Name: count, dtype: int64

# %%
data.loc[data.Status == 'Coming','Status'] = 'Available'

# %%
data.Status.unique()
# Out:
# array(['Available', 'Discontinued'], dtype=object)

# %%
data.isna().sum()
# Out:
# name                  0
# brand                 0
# 2G                    0
# 3G                    0
# 4G                    0
# 5G                    0
# Announced             0
# Status                0
# Weight                0
# Length                0
# Width                 0
# Diameter              0
# SIM                   0
# Display Type          0
# Display Size          0
# ppi                   0
# body ratio            0
# OS                    0
# battery_capacity      0
# Price                 0
# CPU                 279
# ratio                 0
# pixel                 0
# WLAN                  1
# Colors                1
# Sensors              19
# Bluetooth             0
# GPU                 224
# Loudspeaker           0
# 3.5mm jack            0
# Chipset             257
# Network               0
# Internal              0
# Card slot             0
# RAM                   0
# Storage               0
# dtype: int64

# %%
data['n_colors'] = data['Colors'].fillna(method='ffill').apply(lambda x : len(x.split(',')))
# Out:
# C:\Users\Snapp\AppData\Local\Temp\ipykernel_7072\2807774303.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['n_colors'] = data['Colors'].fillna(method='ffill').apply(lambda x : len(x.split(',')))

# %%
data[~data['Sensors'].str.contains('accelerometer', case=False, na=False)].head()
# Out:
#                   name    brand    2G    3G    4G     5G  Announced  \
# 8    alcatel go flip 4  alcatel  True  True  True  False     2021.0
# 9    alcatel go flip 3  alcatel  True  True  True  False     2019.0
# 10   alcatel go flip v  alcatel  True  True  True  False     2019.0
# 59   alcatel pop 7 lte  alcatel  True  True  True  False     2016.0
# 130     alcatel pop 7s  alcatel  True  True  True  False     2014.0
#
#            Status  Weight  Length   Width Diameter        SIM Display Type  \
# 8       Available   133.0  107.3    55.6     19.9    Nano-SIM   TN TFT LCD
# 9       Available   118.0  104.9    53.1     20.1    Nano-SIM   TN TFT LCD
# 10      Available   118.0  104.9    52.8     18.7    Nano-SIM   TN TFT LCD
# 59   Discontinued   295.1    192     110      9.4   Micro-SIM          TFT
# 130  Discontinued   279.0    192     113        9   Micro-SIM      IPS LCD
#
#      Display Size    ppi  body ratio             OS  battery_capacity  Price  \
# 8             2.8  143.0        40.7      KaiOS 3.0            1850.0  120.0
# 9             2.8  143.0        43.6    KaiOS 2.5.2            1350.0   80.0
# 10            2.8  143.0        43.8    KaiOS 2.5.2            1350.0   80.0
# 59            7.0  170.0        65.3  Android 6.0.1            3240.0  130.0
# 130           7.0  170.0        63.6  Android 4.4.2            3240.0  190.0
#
#      CPU ratio     pixel                         WLAN  \
# 8    4.0   4:3   76800.0  Wi-Fi 802.11 b/g/n, hotspot
# 9    4.0   4:3   76800.0  Wi-Fi 802.11 b/g/n, hotspot
# 10   4.0   4:3   76800.0  Wi-Fi 802.11 b/g/n, hotspot
# 59   4.0  16:9  614400.0         Wi-Fi 802.11 a/b/g/n
# 130  4.0  16:9  614400.0           Wi-Fi 802.11 b/g/n
#
#                               Colors Sensors      Bluetooth         GPU  \
# 8                      Midnight Blue     NaN      4.2, A2DP  Adreno 308
# 9                        Prime Black     NaN      4.2, A2DP  Adreno 304
# 10                             Black     NaN      4.2, A2DP  Adreno 304
# 59                             White     NaN  4.1, A2DP, LE         NaN
# 130  White, Black/ color back panels     NaN      4.0, A2DP  Adreno 305
#
#      Loudspeaker  3.5mm jack                                  Chipset  \
# 8           True        True             QM215 Snapdragon 215 (28 nm)
# 9           True        True  Qualcomm MSM8909 Snapdragon 210 (28 nm)
# 10          True        True  Qualcomm MSM8909 Snapdragon 210 (28 nm)
# 59         False        True                                      NaN
# 130         True        True  Qualcomm MSM8926 Snapdragon 400 (28 nm)
#
#                                                Network       Internal  \
# 8                           GSM / HSPA / LTE HSPA, LTE  4GB 512MB RAM
# 9                    GSM / CDMA / HSPA / LTE HSPA, LTE  4GB 512MB RAM
# 10                          GSM / HSPA / LTE HSPA, LTE    8GB 1GB RAM
# 59   GSM / HSPA / LTE HSPA 42.2/5.76 Mbps, LTE Cat4...    8GB 1GB RAM
# 130          GSM / HSPA / LTE HSPA 21.1/5.76 Mbps, LTE    4GB 1GB RAM
#
#                       Card slot  RAM  Storage  n_colors
# 8    microSDHC (dedicated slot)  0.5      4.0         1
# 9    microSDHC (dedicated slot)  0.5      4.0         1
# 10   microSDHC (dedicated slot)  1.0      8.0         1
# 59   microSDHC (dedicated slot)  1.0      8.0         1
# 130  microSDHC (dedicated slot)  1.0      4.0         2

# %%
def split_os_version(row):
    parts = row.split(' ', 1)  
    if len(parts) == 2:
        return parts[0], parts[1] 
    else:
        return parts[0], np.nan 

data[['OS', 'Version']] = data['OS'].apply(lambda x: split_os_version(x)).tolist()

data[['OS']].value_counts()
# Out:
# OS
# Android      2449
# Phone          64
# iOS            60
# HarmonyOS      21
# Symbian        10
# Belle           8
# KaiOS           6
# OS              5
# iPadOS          5
# platform        5
# EMUI            5
# Anna            3
# Tizen           3
# FP1             2
# Mobile          1
# Linux           1
# Firefox         1
# Windows         1
# MeeGo           1
# Name: count, dtype: int64

# %%
data[data['name'].str.contains('watch', case=False, na=False)]
# Out:
# Empty DataFrame
# Columns: [name, brand, 2G, 3G, 4G, 5G, Announced, Status, Weight, Length, Width, Diameter, SIM, Display Type, Display Size, ppi, body ratio, OS, battery_capacity, Price, CPU, ratio, pixel, WLAN, Colors, Sensors, Bluetooth, GPU, Loudspeaker, 3.5mm jack, Chipset, Network, Internal, Card slot, RAM, Storage, n_colors, Version]
# Index: []

# %%
data['OS'] = ['iOS' if x == 'iOS' or x == 'iPadOS' else 'Android' if x=='Android' else 'Windows' if x=='Windows' or x == 'Phone' else 'Others' for x in data.OS]
data[['OS']].value_counts()
# Out:
# OS
# Android    2449
# Others       72
# Windows      65
# iOS          65
# Name: count, dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.dropna().shape
# Out:
# (2176, 38)

# %%
data.dropna()['OS'].value_counts()
# Out:
# OS
# Android    2050
# iOS          62
# Windows      35
# Others       29
# Name: count, dtype: int64

# %%
data[['OS', 'WLAN']].value_counts()
# Out:
# OS       WLAN
# Android  Wi-Fi 802.11 a/b/g/n/ac, dual-band, Wi-Fi Direct                                                                  419
#          Wi-Fi 802.11 b/g/n, Wi-Fi Direct                                                                                  312
#          Wi-Fi 802.11 b/g/n, hotspot                                                                                       212
#          Wi-Fi 802.11 b/g/n                                                                                                174
#          Wi-Fi 802.11 b/g/n, Wi-Fi Direct, hotspot                                                                         161
#          Wi-Fi 802.11 a/b/g/n/ac/6, dual-band, Wi-Fi Direct                                                                121
#          Wi-Fi 802.11 a/b/g/n, dual-band, Wi-Fi Direct, DLNA, hotspot                                                       93
#          Wi-Fi 802.11 a/b/g/n/ac, dual-band, Wi-Fi Direct, DLNA                                                             74
#          Wi-Fi 802.11 b/g/n, DLNA, hotspot                                                                                  65
#          Wi-Fi 802.11 a/b/g/n/ac, dual-band, Wi-Fi Direct, DLNA, hotspot                                                    63
#          Wi-Fi 802.11 a/b/g/n/ac, dual-band                                                                                 59
#          Wi-Fi 802.11 a/b/g/n/ac, dual-band, Wi-Fi Direct, hotspot                                                          59
#          Wi-Fi 802.11 a/b/g/n, dual-band, Wi-Fi Direct, hotspot                                                             50
#          Wi-Fi 802.11 b/g/n, Wi-Fi Direct, DLNA, hotspot                                                                    47
#          Wi-Fi 802.11 a/b/g/n, Wi-Fi Direct                                                                                 42
#          Wi-Fi 802.11 a/b/g/n/ac/6e, dual-band, Wi-Fi Direct                                                                36
# iOS      Wi-Fi 802.11 a/b/g/n/ac, dual-band, hotspot                                                                        25
# Android  Wi-Fi 802.11 a/b/g/n, dual-band, Wi-Fi Direct                                                                      24
#          Wi-Fi 802.11 a/b/g/n/ac, dual-band, DLNA, Wi-Fi Direct                                                             23
#          Wi-Fi 802.11 a/b/g/n, dual-band, hotspot                                                                           23
# Windows  Wi-Fi 802.11 b/g/n                                                                                                 22
# iOS      Wi-Fi 802.11 a/b/g/n/ac/6, dual-band, hotspot                                                                      21
# Others   Wi-Fi 802.11 b/g/n                                                                                                 21
# Android  Wi-Fi 802.11 a/b/g/n                                                                                               20
#          Wi-Fi 802.11 a/b/g/n, dual-band, DLNA, hotspot                                                                     18
#          Wi-Fi 802.11 b/g/n, DLNA                                                                                           18
#          Wi-Fi 802.11 b/g/n, Wi-Fi Direct, DLNA                                                                             15
#          Wi-Fi 802.11 b/g/n, Wi-Fi Direct, hotspot, DLNA                                                                    14
#          Wi-Fi 802.11 a/b/g/n, Wi-Fi Direct, DLNA, hotspot                                                                  14
#          Wi-Fi 802.11 a/b/g/n/ac/6, dual-band                                                                               13
#          Wi-Fi 802.11 b/g, hotspot                                                                                          13
#          Wi-Fi 802.11 b/g/n/ac, dual-band, Wi-Fi Direct                                                                     13
#          Wi-Fi 802.11 b/g/n, hotspot, DLNA                                                                                  12
#          Wi-Fi 802.11 a/b/g/n/ac, Wi-Fi Direct, hotspot                                                                     11
#          Wi-Fi 802.11 b/g                                                                                                   10
#          Yes                                                                                                                10
#          Wi-Fi 802.11 a/b/g/n/ac/6e/7, tri-band, Wi-Fi Direct                                                               10
#          Wi-Fi 802.11 a/b/g/n/ac, Wi-Fi Direct                                                                               9
#          Wi-Fi 802.11 a/b/g/n/ac/6e, tri-band, Wi-Fi Direct                                                                  9
#          Wi-Fi 802.11 b/g/n/ac, Wi-Fi Direct                                                                                 9
#          Wi-Fi 802.11 a/b/g/n/ac/6, dual-band, Wi-Fi Direct, DLNA                                                            9
# Others   Wi-Fi 802.11 a/b/g/n/ac/6, dual-band, Wi-Fi Direct                                                                  9
#          Wi-Fi 802.11 b/g/n, hotspot                                                                                         8
# Windows  Wi-Fi 802.11 b/g/n, hotspot                                                                                         8
# iOS      Wi-Fi 802.11 a/b/g/n, dual-band                                                                                     7
# Windows  Wi-Fi 802.11 b/g/n, DLNA, hotspot                                                                                   6
# Others   No                                                                                                                  6
#          Wi-Fi 802.11 a/b/g/n/ac, dual-band                                                                                  5
# Android  Wi-Fi 802.11 a/b/g/n/ac/6e/7, dual-band, Wi-Fi Direct                                                               5
# iOS      Wi-Fi 802.11 a/b/g/n, dual-band, hotspot                                                                            5
# Windows  Wi-Fi 802.11 a/b/g/n, dual-band, DLNA, hotspot                                                                      5
# Android  Wi-Fi 802.11 a/b/g/n/ac, Wi-Fi Direct, DLNA, hotspot                                                                5
#          Wi-Fi 802.11 a/b/g/n, dual band, Wi-Fi Direct, DLNA, hotspot                                                        4
#          Wi-Fi 802.11 b/g/n/ac, dual-band, Wi-Fi Direct, DLNA                                                                4
#          Wi-Fi 802.11 a/b/g/n, Wi-Fi Direct, hotspot, DLNA                                                                   4
#          Wi-Fi 802.11 a/b/g/n, Wi-Fi Direct, DLNA                                                                            4
#          Wi-Fi 802.11 b/g/n/ac, dual band, hotspot                                                                           4
# Windows  Wi-Fi 802.11 a/b/g/n, dual-band                                                                                     4
#          Wi-Fi 802.11 b/g/n, DLNA                                                                                            4
# Android  Wi-Fi 802.11 b/g/n/ac                                                                                               4
#          Wi-Fi 802.11 a/b/g/n, dual-band, Wi-Fi Direct, hotspot, DLNA                                                        4
#          Wi-Fi 802.11 b/g, hotspot (Android 2.2)                                                                             4
#          Wi-Fi 802.11 a/b/g/n/ac                                                                                             4
#          Wi-Fi 802.11 a/b/g/n, dual band, hotspot                                                                            4
#          Wi-Fi 802.11 b/g/n/ac, dual-band, Wi-Fi Direct, hotspot                                                             3
#          Wi-Fi 802.11 b/g/n, hotspot (Android 2.2)                                                                           3
#          Wi-Fi 802.11 a/b/g/n, dual-band                                                                                     3
#          Wi-Fi 802.11 b/g/n, hotspot, Wi-Fi Direct                                                                           3
#          Wi-Fi 802.11 a/b/g/n, hotspot                                                                                       3
# Others   Wi-Fi 802.11 a/b/g/n/ac, dual-band, Wi-Fi Direct                                                                    3
# Android  Wi-Fi 802.11 а/b/g/n, Wi-Fi Direct                                                                                  3
#          Wi-Fi 802.11 a/b/g/n, dual-band, Wi-Fi Direct, DLNA                                                                 3
#          Wi-Fi 802.11 a/b/g/n, dual-band, hotspot, Wi-Fi Direct, DLNA                                                        3
#          Wi-Fi 802.11 a/b/g/n, dual-band, hotspot, DLNA                                                                      3
#          Wi-Fi 802.11 a/b/g/n/ac, dual-band, DLNA, Wi-Fi Direct, hotspot                                                     3
# Windows  Wi-Fi 802.11 a/b/g/n, dual-band, Wi-Fi Direct                                                                       3
# Others   Wi-Fi 802.11 a/b/g/n/a/6, dual-band, Wi-Fi Direct                                                                   3
# iOS      Wi-Fi 802.11 a/b/g/n/ac/6e, dual-band, hotspot                                                                      3
# Android  Wi-Fi 802.11 a/b/g/n/ac, dual-band, hotspot                                                                         3
#          Wi-Fi 802.11 a/b/g/n, dual-band, DLNA, Wi-Fi Direct, hotspot                                                        3
#          Wi-Fi 802.11 a/b/g/n/ac/6e, tri-band, Wi-Fi Direct, DLNA                                                            3
# Others   Wi-Fi 802.11 b/g/n, Wi-Fi Direct                                                                                    2
#          Wi-Fi 802.11 b/g, UPnP                                                                                              2
#          Wi-Fi 802.11 b/g                                                                                                    2
# Windows  Wi-Fi 802.11 a/b/g/n/ac, dual-band, DLNA, hotspot                                                                   2
# Android  Wi-Fi 802.11 b/g/n, WiMAX 802.16 e, DLNA, hotspot                                                                   2
# Windows  Wi-Fi 802.11 a/b/g/n/ac, dual-band, Wi-Fi Direct, DLNA, hotspot                                                     2
# Others   Wi-Fi 802.11 b/g/n, Wi-Fi Direct, hotspot                                                                           2
# iOS      Wi-Fi 802.11 b/g/n, hotspot                                                                                         2
# Android  Wi-Fi 802.11 b/g/n (3G)Wi-Fi 802.11 a/b/g/n, dual-band (LTE)                                                        2
#          Wi-Fi 802.11 b/g/n, DLNA, Wi-Fi Direct, hotspot                                                                     2
#          Wi-Fi 802.11 a/b/g/n/ac, dual-band,  hotspot                                                                        2
#          Wi-Fi 802.11 a/b/g/n/ac, dual band, hotspot                                                                         2
#          Wi-Fi 802.11 a/b/g/n/ac/6 or 6e (market dependent), dual-band, Wi-Fi Direct                                         2
#          Wi-Fi 802.11 a/b/g/n, dual-band, DLNA, Wi-Fi Direct                                                                 2
#          Wi-Fi 802.11 a/b/g/n/ac/ad, dual-band, Wi-Fi Direct                                                                 2
#          Wi-Fi 802.11 a/b/g/n/ac, dual-band, DLNA, hotspot                                                                   2
#          Wi-Fi 802.11 a/b/g/n, dual band                                                                                     2
#          Wi-Fi 802.11 a/b/g/n, Wi-Fi Direct, hotspot                                                                         2
#          Wi-Fi 802.11 b/g/n, DLNA, hotspot (Android 2.2)                                                                     2
#          Wi-Fi 802.11 b/g/n, DLNA, hotspot (charges may apply)                                                               2
# Others   Yes, hotspot                                                                                                        1
# Android  Wi-Fi 802.11 a/b/g/n/ac/6, dual-band, Wi-Fi DirectWi-Fi 802.11 a/b/g/n/ac, dual-band - India                        1
#          Wi-Fi 802.11 a/b/g/n/ac, dual-band, Wi-Fi Direct (SDM630)Wi-Fi 802.11, b/g/n, Wi-Fi Direct (MSM8937)                1
#          Wi-Fi 802.11 a/b/g/n/ac, dual-band, Wi-Fi Direct (Western Europe, Korea)Wi-Fi 802.11 b/g/n, Wi-Fi Direct (ROW)      1
# Windows  Wi-Fi 802.11 a/b/g/n, dual band, Wi-Fi Direct, DLNA, hotspot                                                        1
# Android  Wi-Fi 802.11 a/b/g/n/ac/6 (Global), Wi-Fi 802.11 a/b/g/n/ac (India)                                                 1
#          Wi-Fi 802.11 a/b/g/n/ac, dual-band, Wi-Fi Direct - STK-AL00Wi-Fi 802.11 b/g/n, Wi-Fi Direct - STK-TL00              1
# Others   Wi-Fi 802.11 b/g, UPnP & DLNA technology                                                                            1
# Android  Wi-Fi 802.11 a/b/g/n/ac/6 (Wi-Fi), Wi-Fi 802.11 a/b/g/n/ac (5G)                                                     1
# Others   Wi-Fi 802.11 b/g/n, DLNA, UPnP technology                                                                           1
# Windows  Wi-Fi 802.11 a/b/g/n, dual-band, Wi-Fi Direct, DLNA, hotspot                                                        1
# Others   Wi-Fi 802.11 b/g, UPnP technology                                                                                   1
#          Wi-Fi 802.11 b/g, Wi-Fi router                                                                                      1
# Android  Wi-Fi 802.11 b/g/n, Hotspot functionality                                                                           1
# Windows  Wi-Fi 802.11 a/b/g/n, dual-band, hotspot                                                                            1
#          Wi-Fi 802.11 b/g/n, hotspot, DLNA                                                                                   1
# iOS      Wi-Fi 802.11 b/g/n                                                                                                  1
# Android  Wi-Fi 802.11 a/b/g/n, Wi-Fi Direct, DLNAorWi-Fi 802.11 b/g/n, Wi-Fi Direct, DLNA                                    1
# iOS      Wi-Fi 802.11 a/b/g/n/ac, hotspot                                                                                    1
# Android  Wi-Fi 802.11 a/b/g/n, dual band, DLNA                                                                               1
# Windows  Wi-Fi 802.11b/g/n, DLNA                                                                                             1
#          Wi-Fi 802.11b/g/n                                                                                                   1
# Android  Wi-Fi 802.11 a/b/g/n, dual-band, DLNA, hotspot; WiMAX 802.16 e                                                      1
# Others   Wi-Fi 802.11 a/b/g/n/ac/6, tri-band (dual-band for GOT-W29), Wi-Fi Direct                                           1
# Windows  Wi-Fi 802.11 b/g/n, Wi-Fi Direct                                                                                    1
# Android  Wi-Fi 802.11 a/b/g/n, dual-band, Wi-Fi Direct, DLNA, hotspot; WiMax                                                 1
#          Wi-Fi 802.11 a/b/g/n/a/6, dual-band, Wi-Fi Direct                                                                   1
#          Wi-Fi 802.11 a/b/g/n/ac, Wi-Fi 6 (market dependent), dual-band, Wi-Fi Direct                                        1
# Windows  Wi-Fi 802.11 a/b/g/n/ac, dual-band, hotspot                                                                         1
#          Wi-Fi 802.11 a/b/g/n/ac, dual-band, Wi-Fi Direct, hotspot                                                           1
# Android  Wi-Fi 802.11 a/b/g/n/ac/6/i/r, dual-band, Wi-Fi Direct                                                              1
#          Wi-Fi 802.11 a/b/g/n/ac/6e, dual-band or tri-band (region dependent), Wi-Fi Direct, DLNA                            1
#          Wi-Fi 802.11 a/b/g/n/ac/6e, dual-band                                                                               1
#          Wi-Fi 802.11 b/g/n (Android v2.2)                                                                                   1
#          Wi-Fi 802.11 b/g/n, hotspot, DLNA, UMA                                                                              1
#          Wi-Fi 802.11 b/g/n or Wi-Fi 802.11 a/b/g/n/ac, dual-band                                                            1
#          Wi-Fi 802.11 b/g/n or a/b/g/n, Wi-Fi Direct                                                                         1
#          Wi-Fi 802.11 b/g/n, (DLNA - carrier dependent)                                                                      1
#          Wi-Fi 802.11 b/g/n, dual-band, Wi-Fi Direct                                                                         1
#          Wi-Fi 802.11 b/g/n, dual band, DLNA                                                                                 1
#          Wi-Fi 802.11 b/g/n, WiMAX, hotspot (charges may apply)                                                              1
#          Wi-Fi 802.11 b/g/n, WiMAX, hotspot                                                                                  1
#          Wi-Fi 802.11 b/g/n, WiMAX 802.16 e, hotspot, DLNA                                                                   1
#          Wi-Fi 802.11 b/g/n, WiMAX 802.16 e, hotspot                                                                         1
#          Wi-Fi 802.11 b/g/n, Wi-Fi Direct, hotspotWi-Fi 802.11 a/b/g/n, Wi-Fi Direct, hotspot - USA model                    1
#          Wi-Fi 802.11 b/g/n, Wi-Fi Direct, hotspot, DLNA (optional)                                                          1
#          Wi-Fi 802.11 b/g/n, DLNA, WiMAX 802.16 e                                                                            1
#          Wi-Fi 802.11 a/b/g                                                                                                  1
#          Wi-Fi 802.11 b/g/n, Wi-Fi Direct, DLNAorWi-Fi 802.11 a/b/g/n/ac, dual-band, Wi-Fi Direct, DNLA                      1
#          Wi-Fi 802.11 b/g/n (LX2/LX3) or a/b/g/n/ac (LX1/LX2J), Wi-Fi Direct                                                 1
#          Wi-Fi 802.11 b/g/n/ac, Wi-Fi Direct, DLNA                                                                           1
# Others   Wi-Fi 802.11 a/b/g/n/ac/6, dual-band                                                                                1
# Android  Wi-Fi 802.11 b/g, hotspot, DLNA                                                                                     1
#          Wi-Fi 802.11 a/b/g/n/ac/6e, dual-band, Wi-Fi Direct, DLNA                                                           1
# Others   Wi-Fi 802.11 a/b/g/n, dual-band, Wi-Fi Direct                                                                       1
#          Wi-Fi 802.11 a/b/g/n, dual-band, DLNA, hotspot                                                                      1
# Android  Wi-Fi 802.11 a/b/g/n/ac/k/v/r, dual-band, Wi-Fi Direct                                                              1
#          Wi-Fi 802.11 a/b/g/n/ac/mc/6e, tri-band, Wi-Fi Direct                                                               1
#          Wi-Fi 802.11, b/g/n, Wi-Fi Direct                                                                                   1
#          Wi-Fi 802.11 а/b/g/n/ac, dual-band, Wi-Fi Direct                                                                    1
#          Wi-Fi 802.11 a/g/n                                                                                                  1
#          Wi-Fi 802.11 b/g/nWi-Fi 802.11 a/b/g/n/ac, Wi-Fi Direct - USA version                                               1
#          Wi-Fi 802.11 b/g/n; WiMAX, hotspot (Android 2.2)                                                                    1
#          Wi-Fi 802.11 b/g/n; DLNA                                                                                            1
#          Wi-Fi 802.11 b/g/n/ac, dual-band, hotspot                                                                           1
#          Wi-Fi 802.11 b/g, DLNA, hotspot                                                                                     1
#          Wi-Fi 802.11 b/g, WiMAX 802.16 e (Wi-Fi router)                                                                     1
#          Wi-Fi 802.11 b/g, hotspot (charges may apply)                                                                       1
#          No                                                                                                                  1
# Name: count, dtype: int64

# %%
data[['OS', 'Card slot']].value_counts() #microsd, microsdhc, microsdxc, no, nano memory, unspecified
# Out:
# OS       Card slot
# Android  microSDXC (dedicated slot)                                                                              853
#          microSDHC (dedicated slot)                                                                              550
#          microSDXC (uses shared SIM slot)                                                                        345
#          No                                                                                                      334
#          microSDXC                                                                                               173
# iOS      No                                                                                                       65
# Android  microSDXC (uses shared SIM slot) - dual SIM model only                                                   37
# Windows  No                                                                                                       36
# Android  microSDHC (dedicated slot), 2 GB included                                                                33
#          NM (Nano Memory), up to 256GB (uses shared SIM slot)                                                     32
# Others   microSDHC (dedicated slot)                                                                               25
# Windows  microSDXC (dedicated slot)                                                                               24
# Android  microSDHC (dedicated slot), 8 GB included                                                                19
#          microSDHC                                                                                                17
# Others   No                                                                                                       14
#          NM (Nano Memory), up to 256GB (uses shared SIM slot)                                                      9
# Android  microSDHC (dedicated slot), 4 GB included                                                                 9
#          microSDHC (dedicated slot), 16 GB included                                                                9
#          microSDXC (dedicated slot) - single-SIM modelmicroSDXC (uses shared SIM slot) - dual-SIM model            6
# Others   microSDHC (dedicated slot), 2 GB included                                                                 6
# Android  Unspecified                                                                                               5
# Others   microSDXC (uses shared SIM slot)                                                                          4
# Windows  microSDHC (dedicated slot)                                                                                4
# Others   microSDHC (dedicated slot), 4 GB included                                                                 4
# Android  microSD                                                                                                   3
# Others   microSDHC                                                                                                 2
#          microSDXC                                                                                                 2
#          NM (Nano Memory), up to 256GB (dedicated slot)                                                            2
# Android  microSDXC (uses shared SIM slot) - dual-SIM model                                                         2
# Others   microSDXC (dedicated slot)                                                                                2
# Android  NM (Nano Memory), up to 256GB (dedicated slot)                                                            2
#          microSDXC (dedicated slot), 2 GB included                                                                 2
#          microSDXC (dedicated slot) - single-SIM model                                                             2
#          microSDHC (dedicated slot), 1 GB included                                                                 2
#          microSDHC (uses shared SIM slot)                                                                          2
#          microSDXC (uses shared SIM slot) - USA onlymicroSDXC (dedicated slot) - International                     1
#          microSDHC (uses shared SIM slot) - mediatek modelmicroSDXC (uses shared SIM slot) - snapdragon model      1
#          SD, up to 32 GB                                                                                           1
#          Yes, up to 64 GB (dedicated slot)                                                                         1
# Windows  microSDHC                                                                                                 1
# Android  microSDHC (dedicated slot), 32 GB included                                                                1
#          microSDXC (6GB model only)                                                                                1
# Others   microSDHC (dedicated slot), 8 GB included                                                                 1
# Android  microSDXC (only single sim model)                                                                         1
#          microSDXC (dedicated slot) - Chinese version only                                                         1
#          microSDXC (dedicated slot) - F620SmicroSDHC (dedicated slot) - H650E                                      1
# Others   microSD                                                                                                   1
# Android  microSDXC (dedicated slot) - single-SIM modelNo microSDXC - dual-SIM model                                1
#          microSDXC (dedicated slot); microSDHC (SGP351)                                                            1
#          microSDXC (dedicated slot), 16 GB included                                                                1
# Name: count, dtype: int64

# %%
data[['SIM', 'OS']].value_counts()
# Out:
# SIM        OS
# Nano-SIM   Android    1378
# Micro-SIM  Android     579
# Mini-SIM   Android     437
# eSIM       Android      55
#            iOS          41
# Micro-SIM  Windows      37
# Nano-SIM   Others       33
# Mini-SIM   Others       26
#            Windows      20
# Nano-SIM   iOS          16
# Micro-SIM  Others       13
# Nano-SIM   Windows       8
# Micro-SIM  iOS           7
# Mini-SIM   iOS           1
# Name: count, dtype: int64

# %%
def replace_with_allowed_value(value):
    card_types = ['microsdxc', 'microsdhc', 'microsd', 'nano memory', 'no', 'unspecified']
    value_lower = value.lower()

    for card_type in card_types:
        if card_type in value_lower:
            return card_type
    return value_lower

data['Card slot'] = data['Card slot'].apply(replace_with_allowed_value)

data[['OS', 'Card slot']].value_counts()
# Out:
# OS       Card slot
# Android  microsdxc                            1429
#          microsdhc                             642
#          no                                    334
# iOS      no                                     65
# Others   microsdhc                              38
# Windows  no                                     36
# Android  nano memory                            34
# Windows  microsdxc                              24
# Others   no                                     14
#          nano memory                            11
#          microsdxc                               8
# Windows  microsdhc                               5
# Android  unspecified                             5
#          microsd                                 3
#          yes, up to 64 gb (dedicated slot)       1
#          sd, up to 32 gb                         1
# Others   microsd                                 1
# Name: count, dtype: int64

# %%
data[~data['Card slot'].isin(['microsdxc', 'microsdhc', 'microsd', 'nano memory', 'no', 'unspecified'])]
# Out:
#                          name   brand    2G    3G     4G     5G  Announced  \
# 1723       huawei ascend mate  huawei  True  True  False  False     2013.0
# 3052  sony xperia tablet s 3g    sony  True  True  False  False     2012.0
#
#             Status  Weight  Length    Width Diameter        SIM  \
# 1723  Discontinued   198.0  163.5     85.7      9.9   Micro-SIM
# 3052  Discontinued   585.0  239.8    174.4      8.8    Mini-SIM
#
#           Display Type  Display Size    ppi  body ratio       OS  \
# 1723          IPS+ LCD           6.1  241.0        73.2  Android
# 3052  LED-backlit LCD,           9.4  161.0        61.3  Android
#
#       battery_capacity  Price  CPU  ratio      pixel  \
# 1723            4050.0  230.0  4.0   16:9   921600.0
# 3052            6000.0  260.0  4.0  16:10  1024000.0
#
#                                                    WLAN  \
# 1723  Wi-Fi 802.11 a/b/g/n, dual-band, Wi-Fi Direct,...
# 3052           Wi-Fi 802.11 a/b/g/n, dual-band, hotspot
#
#                          Colors                                  Sensors  \
# 1723  Crystal Black, Pure White  Accelerometer, gyro, proximity, compass
# 3052               Black/Silver             Accelerometer, gyro, compass
#
#                Bluetooth             GPU  Loudspeaker  3.5mm jack  \
# 1723  4.0, A2DP, EDR, LE  Vivante GC4000         True        True
# 3052           3.0, A2DP     ULP GeForce        False        True
#
#              Chipset                         Network  \
# 1723     Huawei K3V2  GSM / HSPA HSPA 42.2/5.76 Mbps
# 3052  Nvidia Tegra 3                 GSM / HSPA HSPA
#
#                                       Internal  \
# 1723                               8GB 2GB RAM
# 3052  16GB 1GB RAM, 32GB 1GB RAM, 64GB 1GB RAM
#
#                               Card slot  RAM  Storage  n_colors Version
# 1723  yes, up to 64 gb (dedicated slot)  2.0      8.0         2     4.1
# 3052                    sd, up to 32 gb  1.0     16.0         1   4.0.3

# %%
data[data.brand == 'sony']['Card slot'].value_counts()
# Out:
# Card slot
# microsdxc          77
# microsdhc          40
# no                  4
# sd, up to 32 gb     1
# Name: count, dtype: int64

# %%
data.loc[~data['Card slot'].isin(['microsdxc', 'microsdhc', 'microsd', 'nano memory', 'no', 'unspecified']), 'Card slot'] = 'microsdxc'

# %%
data[['OS', 'n_colors']].value_counts()
# Out:
# OS       n_colors
# Android  2           707
#          3           694
#          1           472
#          4           374
#          5           115
#          6            44
# Windows  1            24
# Others   3            22
# Windows  4            19
# iOS      3            17
#          2            17
# Others   2            16
# Android  7            16
# iOS      4            15
# Others   4            12
# Android  9            12
#          8            11
# iOS      6            10
# Others   1             9
# Windows  2             8
#          5             8
# Others   5             8
# iOS      5             5
# Android  10            4
# Windows  3             3
# Others   9             3
# Windows  7             2
# Others   6             2
# Windows  6             1
# iOS      1             1
# Name: count, dtype: int64

# %%
data[['OS','Storage']].value_counts()
# Out:
# OS       Storage
# Android  16.000000     543
#          32.000000     433
#          64.000000     358
#          128.000000    324
#          8.000000      299
#          4.000000      279
#          256.000000     82
#          0.500000       54
# Windows  8.000000       30
# iOS      64.000000      19
#          16.000000      19
# Windows  16.000000      18
# Android  2.000000       17
#          1.000000       16
# iOS      128.000000     16
# Others   128.000000     16
#          8.000000       13
# Windows  4.000000        9
# Others   4.000000        8
# Android  0.250000        8
# iOS      32.000000       7
# Windows  32.000000       7
# Others   16.000000       5
# Android  512.000000      5
#          0.146484        4
# Others   256.000000      4
#          0.062500        4
#          0.039062        3
# Android  0.156250        3
#          3.000000        3
# iOS      8.000000        3
# Android  1.100000        3
# Others   64.000000       3
#          512.000000      2
# Android  11.000000       2
# Others   2.000000        2
# Android  2.900000        2
#          1.500000        2
#          0.375000        2
#          0.154297        2
# Windows  64.000000       1
# Others   32.000000       1
# Android  0.135742        1
# Others   0.058594        1
#          0.500000        1
#          0.375000        1
# Android  0.166016        1
#          0.175781        1
#          0.253906        1
#          0.263672        1
#          0.562500        1
#          13.200000       1
# Others   0.048828        1
# Android  0.136719        1
# Others   0.068359        1
#          0.125000        1
#          0.156250        1
#          0.244141        1
#          0.250000        1
#          0.263672        1
#          0.332031        1
# iOS      256.000000      1
# Name: count, dtype: int64

# %%
data['Length'].unique()
# Out:
# array(['146.7 ', '156.4 ', '137.6 ', '165.6 ', '155.9 ', '165.2 ',
#        '159.2 ', '107.3 ', '104.9 ', '243.3 ', '165 ', '158.7 ', '146.1 ',
#        '174.5 ', '164.9 ', '149.1 ', '209.5 ', '146.4 ', '136.6 ',
#        '142.5 ', '162.1 ', '152.3 ', '162 ', '153.5 ', '147.1 ', '147.5 ',
#        '148.6 ', '148 ', '141.5 ', '150.9 ', '145 ', '140.7 ', '152.6 ',
#        '192 ', '153.9 ', '147 ', '168.5 ', '151.9 ', '141 ', '145.8 ',
#        '133.6 ', '152.7 ', '134.6 ', '209 ', '191 ', '189 ', '245.2 ',
#        '132.2 ', '121.3 ', '112.2 ', '121.6 ', '132.5 ', '160.5 ',
#        '112.5 ', '122 ', '123 ', '129 ', '136.5 ', '129.5 ', '151 ',
#        '130.3 ', '121.5 ', '131.5 ', '138 ', '158.5 ', '133.5 ', '127.1 ',
#        '115 ', '140.4 ', '143 ', '134.4 ', '133 ', '131 ', '144 ',
#        '114.5 ', '129.8 ', '119.9 ', '116 ', '128 ', '112 ', '159.9 ',
#        '146.6 ', '160.9 ', '147.6 ', '280.6 ', '160.7 ', '160.8 ',
#        '138.4 ', '250.6 ', '158 ', '203.2 ', '157.5 ', '143.6 ', '240 ',
#        '158.4 ', '305.7 ', '158.2 ', '138.3 ', '123.8 ', '200 ', '158.1 ',
#        '138.1 ', '124.4 ', '241.2 ', '115.2 ', '242.8 ', '163.8 ',
#        '146.5 ', '165.1 ', '171 ', '159.1 ', '157.9 ', '147.3 ', '158.8 ',
#        '159 ', '153 ', '160.6 ', '156.9 ', '155.4 ', '155.7 ', '154 ',
#        '150.5 ', '204 ', '153.4 ', '141.2 ', '149.5 ', '242.3 ', '154.3 ',
#        '188 ', '205.4 ', '151.4 ', '151.5 ', '149 ', '146.9 ', '186.4 ',
#        '156 ', '146 ', '135 ', '144.5 ', '152.4 ', '158.9 ', '152.5 ',
#        '164.6 ', '143.7 ', '148.1 ', '151.8 ', '156.5 ', '194.3 ', '196 ',
#        '148.2 ', '132.1 ', '136.8 ', '213 ', '257.4 ', '143.4 ', '143.5 ',
#        '166.9 ', '132 ', '129.3 ', '196.8 ', '164.8 ', '196.4 ', '198.5 ',
#        '137.9 ', '164.2 ', '168.3 ', '173 ', '159.4 ', '164.7 ', '164.5 ',
#        '163.4 ', '145.9 ', '152.9 ', '156.1 ', '162.4 ', '160.2 ', '208 ',
#        '142.9 ', '163 ', '160 ', '124.5 ', '194.4 ', '155 ', '147.8 ',
#        '163.9 ', '159.6 ', '153.6 ', '156.8 ', '124.8 ', '161.4 ',
#        '144.3 ', '154.4 ', '156.7 ', '157.2 ', '124.3 ', '152.2 ',
#        '147.7 ', '126.8 ', '148.4 ', '160.1 ', '154.5 ', '142 ', '143.3 ',
#        '164 ', '165.5 ', '139.8 ', '163.5 ', '145.7 ', '187.5 ', '127 ',
#        '144.8 ', '145.1 ', '150.6 ', '136 ', '117 ', '130 ', '137 ',
#        '205 ', '137.5 ', '125 ', '157 ', '124 ', '116.5 ', '161 ', '150 ',
#        '134 ', '161.2 ', '104 ', '197 ', '120 ', '103 ', '98.7 ',
#        '166.6 ', '239.2 ', '244 ', '257.9 ', '241.5 ', '164.1 ', '166.3 ',
#        '165.7 ', '167.1 ', '147.9 ', '156.2 ', '154.2 ', '156.6 ',
#        '148.5 ', '144.6 ', '157.7 ', '146.8 ', '140 ', '139.7 ', '150.1 ',
#        '228.2 ', '151.7 ', '143.8 ', '139.9 ', '145.4 ', '137.4 ',
#        '125.7 ', '132.4 ', '143.1 ', '128.5 ', '145.5 ', '134.5 ',
#        '131.8 ', '107.7 ', '134.8 ', '126 ', '137.8 ', '118.5 ', '129.7 ',
#        '120.5 ', '119.5 ', '107.2 ', '121.9 ', '130.9 ', '120.3 ',
#        '128.8 ', '102.8 ', '119 ', '126.1 ', '251 ', '122.2 ', '114.4 ',
#        '120.7 ', '101.3 ', '109.1 ', '195.4 ', '122.9 ', '103.8 ',
#        '117.5 ', '119.7 ', '116.9 ', '106.8 ', '163.7 ', '261.9 ',
#        '164.3 ', 'Unfolded: 170 ', '249.2 ', '162.2 ', '240.2 ', '161.5 ',
#        '162.9 ', '286.5 ', '246 ', '148.9 ', '163.3 ', '161.1 ', '162.3 ',
#        '257 ', '157.4 ', '199.7 ', '155.2 ', '160.4 ', '159.8 ', '156.3 ',
#        '163.1 ', '206.4 ', '174.6 ', '177.6 ', '204.2 ', '157.8 ', '243 ',
#        '243.4 ', '158.3 ', '157.6 ', '258.7 ', '212.6 ', '213.3 ',
#        '229.8 ', '241.3 ', '142.2 ', '211.1 ', '145.3 ', '147.2 ', '152 ',
#        '215.5 ', '259.1 ', '191.8 ', '134.2 ', '239.8 ', '157.1 ',
#        '159.3 ', '149.8 ', '214.8 ', '135.9 ', '182.7 ', '144.9 ',
#        '122.6 ', '248.5 ', '210.6 ', '122.1 ', '131.2 ', '214.4 ',
#        '183.5 ', '193.4 ', '132.6 ', '123.3 ', '139.5 ', '132.8 ',
#        '193.8 ', '132.7 ', '136.2 ', '125.2 ', '122.5 ', '116.8 ',
#        '115.8 ', '193 ', '106.5 ', '122.3 ', '127.4 ', '116.1 ', '129.9 ',
#        '190 ', '118 ', '116.3 ', '110 ', '163.6 ', '162.7 ', '164.4 ',
#        '172.6 ', '170.5 ', '166.8 ', '165.4 ', '162.5 ', '160.3 ',
#        '215.4 ', '197.8 ', '269.1 ', '263.7 ', '251.2 ', '207.1 ',
#        '285.6 ', '258 ', '256.8 mm ', '258.4 ', '176.2 ', '264.3 ',
#        '169.2 ', '244.2 ', '154.7 ', '198.2 ', '199.1 ', '176.3 ',
#        '177.9 ', '155.1 ', '153.8 ', '247 ', '194.8 ', '210 ', '211 ',
#        '141.9 ', '253 ', '173.9 ', '175 ', '179.8 ', '141.7 ', '246.9 ',
#        '186 ', '186.6 ', '149.9 ', '142.8 ', '121 ', '146.3 ', '123.5 ',
#        '333 ', '255 ', '209.8 ', '140.2 ', '140.5 ', '139.6 ', '264.1 ',
#        '217 ', '198 ', '261 ', '170 ', '190.5 ', '125.6 ', '195.1 ',
#        '126.6 ', '132.3 ', '130.5 ', '166.5 ', '166.2 ', '166.4 ',
#        '165.8 ', '247.2 ', '161.3 ', '153.2 ', '148.7 ', '216.2 ',
#        '155.6 ', '133.9 ', '256.2 ', '159.7 ', '151.6 ', '210.8 ',
#        '133.8 ', '149.4 ', '142.6 ', '131.9 ', '254.3 ', '117.7 ',
#        '140.8 ', '142.7 ', '138.7 ', '133.3 ', '122.7 ', '127.5 ',
#        '124.1 ', '149.3 ', '152.1 ', '189.2 ', '137.7 ', '127.2 ',
#        '131.6 ', '260.9 ', '138.2 ', '216.9 ', '129.6 ', '109.4 ',
#        '150.2 ', '102 ', '138.5 ', '128.4 ', '136.9 ', '131.7 ', '118.4 ',
#        '102.9 ', '102.6 ', '134.9 ', '117.9 ', '127.8 ', '130.8 ',
#        '118.3 ', '111 ', '134.7 ', '132.9 ', '119.1 ', '113.8 ', '125.5 ',
#        '135.4 ', '113.4 ', '114 ', '113.5 ', '108 ', '123.9 ', '109 ',
#        '168 ', '166 ', '247.5 ', '169.9 ', '171.4 ', '169.4 ', '247.6 ',
#        '173.8 ', '171.6 ', '177.7 ', '168.9 ', '131.4 ', '171.9 ',
#        '165.9 ', '171.7 ', '154.8 ', '149.7 ', '151.1 ', '140.9 ',
#        '148.8 ', '139.4 ', '121.7 ', '141.4 ', '115.5 ', '99.5 ',
#        '162.8 ', '99.6 ', '100.3 ', '130.4 ', '99.2 ', '127.9 ', '118.1 ',
#        '115.4 ', '105.8 ', '117.2 ', '111.3 ', '112.3 ', '117.1 ',
#        '117.3 ', '123.7 ', '170.2 ', '167 ', '150.3 ', '254 ', '137.1 ',
#        '213.4 ', '127.3 ', '150.7 ', '266 ', '179.4 ', '131.3 ', '128.7 ',
#        '130.6 ', '139 ', '129.4 ', '113 ', '161.9 ', '279.7 ', '279 ',
#        '170.6 ', '137.3 ', '161.8 ', '168.6 ', '158.6 ', '154.1 ',
#        '166.1 ', '215 ', '155.3 ', '147.4 ', '141.3 ', '140.3 ', '162.6 ',
#        '118.6 ', '119.4 ', '114.3 ', '115.1 ', '202 ', '128.6 ', '125.9 ',
#        '168.1 ', '152.8 ', '163.2 ', '254.7 ', 'Unfolded: 173.3 ',
#        '165.3 ', '168.7 ', '177.8 ', '155.5 ', '245.6 ', '200.2 ',
#        '161.6 ', '174.1 ', '139.2 ', '145.2 ', '144.4 ', '154.6 ',
#        '145.6 ', '139.3 ', '173.1 ', '169 ', '213.8 ', '285.4 ', '326.4 ',
#        '167.7 ', '242.9 ', '168.8 ', '285 ', '253.8 ', '246.8 ', '167.2 ',
#        '284.8 ', '244.5 ', '146.2 ', '243.5 ', '141.6 ', '245 ', '206.6 ',
#        '249.3 ', '260 ', '149.2 ', '127.6 ', '212.1 ', '143.2 ', '159.5 ',
#        '237.3 ', '142.3 ', '186.9 ', '142.4 ', '161.7 ', '254.2 ',
#        '130.1 ', '124.6 ', '198.6 ', '121.4 ', '142.1 ', '241.9 ',
#        '242.5 ', '208.4 ', '208.3 ', '151.3 ', '109.9 ', '144.7 ',
#        '128.9 ', '213.1 ', '131.1 ', '109.8 ', '212.8 ', '247.3 ',
#        '133.1 ', '121.2 ', '106 ', '295.6 ', '295.5 ', '243.1 ', '219 ',
#        '151.2 ', '167.6 ', '105 ', '136.7 ', '113.2 ', '122.4 ', '125.3 ',
#        '262 ', '126.2 ', '112.8 ', '110.1 ', '137.2 ', '112.7 ', '230.9 ',
#        '256.6 ', '110.4 ', '193.7 ', '123.2 ', '135.5 ', '113.1 ',
#        '196.6 ', '115.6 ', '196.7 ', '115.9 ', '256.7 ', '108.6 ',
#        '112.4 ', '110.2 ', '110.5 ', '124.7 ', '190.1 '], dtype=object)

# %%
def length_to_float(row):
    stripped = row.strip()
    parts= stripped.split(' ')
    if len(parts) == 2:
        if parts[1] == 'mm':
           return float(parts[0])
        return float(parts[1])
    return float(parts[0])

# %%
data['Length'] = data['Length'].apply(length_to_float)

# %%
data['Length'].unique()
# Out:
# array([146.7, 156.4, 137.6, 165.6, 155.9, 165.2, 159.2, 107.3, 104.9,
#        243.3, 165. , 158.7, 146.1, 174.5, 164.9, 149.1, 209.5, 146.4,
#        136.6, 142.5, 162.1, 152.3, 162. , 153.5, 147.1, 147.5, 148.6,
#        148. , 141.5, 150.9, 145. , 140.7, 152.6, 192. , 153.9, 147. ,
#        168.5, 151.9, 141. , 145.8, 133.6, 152.7, 134.6, 209. , 191. ,
#        189. , 245.2, 132.2, 121.3, 112.2, 121.6, 132.5, 160.5, 112.5,
#        122. , 123. , 129. , 136.5, 129.5, 151. , 130.3, 121.5, 131.5,
#        138. , 158.5, 133.5, 127.1, 115. , 140.4, 143. , 134.4, 133. ,
#        131. , 144. , 114.5, 129.8, 119.9, 116. , 128. , 112. , 159.9,
#        146.6, 160.9, 147.6, 280.6, 160.7, 160.8, 138.4, 250.6, 158. ,
#        203.2, 157.5, 143.6, 240. , 158.4, 305.7, 158.2, 138.3, 123.8,
#        200. , 158.1, 138.1, 124.4, 241.2, 115.2, 242.8, 163.8, 146.5,
#        165.1, 171. , 159.1, 157.9, 147.3, 158.8, 159. , 153. , 160.6,
#        156.9, 155.4, 155.7, 154. , 150.5, 204. , 153.4, 141.2, 149.5,
#        242.3, 154.3, 188. , 205.4, 151.4, 151.5, 149. , 146.9, 186.4,
#        156. , 146. , 135. , 144.5, 152.4, 158.9, 152.5, 164.6, 143.7,
#        148.1, 151.8, 156.5, 194.3, 196. , 148.2, 132.1, 136.8, 213. ,
#        257.4, 143.4, 143.5, 166.9, 132. , 129.3, 196.8, 164.8, 196.4,
#        198.5, 137.9, 164.2, 168.3, 173. , 159.4, 164.7, 164.5, 163.4,
#        145.9, 152.9, 156.1, 162.4, 160.2, 208. , 142.9, 163. , 160. ,
#        124.5, 194.4, 155. , 147.8, 163.9, 159.6, 153.6, 156.8, 124.8,
#        161.4, 144.3, 154.4, 156.7, 157.2, 124.3, 152.2, 147.7, 126.8,
#        148.4, 160.1, 154.5, 142. , 143.3, 164. , 165.5, 139.8, 163.5,
#        145.7, 187.5, 127. , 144.8, 145.1, 150.6, 136. , 117. , 130. ,
#        137. , 205. , 137.5, 125. , 157. , 124. , 116.5, 161. , 150. ,
#        134. , 161.2, 104. , 197. , 120. , 103. ,  98.7, 166.6, 239.2,
#        244. , 257.9, 241.5, 164.1, 166.3, 165.7, 167.1, 147.9, 156.2,
#        154.2, 156.6, 148.5, 144.6, 157.7, 146.8, 140. , 139.7, 150.1,
#        228.2, 151.7, 143.8, 139.9, 145.4, 137.4, 125.7, 132.4, 143.1,
#        128.5, 145.5, 134.5, 131.8, 107.7, 134.8, 126. , 137.8, 118.5,
#        129.7, 120.5, 119.5, 107.2, 121.9, 130.9, 120.3, 128.8, 102.8,
#        119. , 126.1, 251. , 122.2, 114.4, 120.7, 101.3, 109.1, 195.4,
#        122.9, 103.8, 117.5, 119.7, 116.9, 106.8, 163.7, 261.9, 164.3,
#        170. , 249.2, 162.2, 240.2, 161.5, 162.9, 286.5, 246. , 148.9,
#        163.3, 161.1, 162.3, 257. , 157.4, 199.7, 155.2, 160.4, 159.8,
#        156.3, 163.1, 206.4, 174.6, 177.6, 204.2, 157.8, 243. , 243.4,
#        158.3, 157.6, 258.7, 212.6, 213.3, 229.8, 241.3, 142.2, 211.1,
#        145.3, 147.2, 152. , 215.5, 259.1, 191.8, 134.2, 239.8, 157.1,
#        159.3, 149.8, 214.8, 135.9, 182.7, 144.9, 122.6, 248.5, 210.6,
#        122.1, 131.2, 214.4, 183.5, 193.4, 132.6, 123.3, 139.5, 132.8,
#        193.8, 132.7, 136.2, 125.2, 122.5, 116.8, 115.8, 193. , 106.5,
#        122.3, 127.4, 116.1, 129.9, 190. , 118. , 116.3, 110. , 163.6,
#        162.7, 164.4, 172.6, 170.5, 166.8, 165.4, 162.5, 160.3, 215.4,
#        197.8, 269.1, 263.7, 251.2, 207.1, 285.6, 258. , 256.8, 258.4,
#        176.2, 264.3, 169.2, 244.2, 154.7, 198.2, 199.1, 176.3, 177.9,
#        155.1, 153.8, 247. , 194.8, 210. , 211. , 141.9, 253. , 173.9,
#        175. , 179.8, 141.7, 246.9, 186. , 186.6, 149.9, 142.8, 121. ,
#        146.3, 123.5, 333. , 255. , 209.8, 140.2, 140.5, 139.6, 264.1,
#        217. , 198. , 261. , 190.5, 125.6, 195.1, 126.6, 132.3, 130.5,
#        166.5, 166.2, 166.4, 165.8, 247.2, 161.3, 153.2, 148.7, 216.2,
#        155.6, 133.9, 256.2, 159.7, 151.6, 210.8, 133.8, 149.4, 142.6,
#        131.9, 254.3, 117.7, 140.8, 142.7, 138.7, 133.3, 122.7, 127.5,
#        124.1, 149.3, 152.1, 189.2, 137.7, 127.2, 131.6, 260.9, 138.2,
#        216.9, 129.6, 109.4, 150.2, 102. , 138.5, 128.4, 136.9, 131.7,
#        118.4, 102.9, 102.6, 134.9, 117.9, 127.8, 130.8, 118.3, 111. ,
#        134.7, 132.9, 119.1, 113.8, 125.5, 135.4, 113.4, 114. , 113.5,
#        108. , 123.9, 109. , 168. , 166. , 247.5, 169.9, 171.4, 169.4,
#        247.6, 173.8, 171.6, 177.7, 168.9, 131.4, 171.9, 165.9, 171.7,
#        154.8, 149.7, 151.1, 140.9, 148.8, 139.4, 121.7, 141.4, 115.5,
#         99.5, 162.8,  99.6, 100.3, 130.4,  99.2, 127.9, 118.1, 115.4,
#        105.8, 117.2, 111.3, 112.3, 117.1, 117.3, 123.7, 170.2, 167. ,
#        150.3, 254. , 137.1, 213.4, 127.3, 150.7, 266. , 179.4, 131.3,
#        128.7, 130.6, 139. , 129.4, 113. , 161.9, 279.7, 279. , 170.6,
#        137.3, 161.8, 168.6, 158.6, 154.1, 166.1, 215. , 155.3, 147.4,
#        141.3, 140.3, 162.6, 118.6, 119.4, 114.3, 115.1, 202. , 128.6,
#        125.9, 168.1, 152.8, 163.2, 254.7, 173.3, 165.3, 168.7, 177.8,
#        155.5, 245.6, 200.2, 161.6, 174.1, 139.2, 145.2, 144.4, 154.6,
#        145.6, 139.3, 173.1, 169. , 213.8, 285.4, 326.4, 167.7, 242.9,
#        168.8, 285. , 253.8, 246.8, 167.2, 284.8, 244.5, 146.2, 243.5,
#        141.6, 245. , 206.6, 249.3, 260. , 149.2, 127.6, 212.1, 143.2,
#        159.5, 237.3, 142.3, 186.9, 142.4, 161.7, 254.2, 130.1, 124.6,
#        198.6, 121.4, 142.1, 241.9, 242.5, 208.4, 208.3, 151.3, 109.9,
#        144.7, 128.9, 213.1, 131.1, 109.8, 212.8, 247.3, 133.1, 121.2,
#        106. , 295.6, 295.5, 243.1, 219. , 151.2, 167.6, 105. , 136.7,
#        113.2, 122.4, 125.3, 262. , 126.2, 112.8, 110.1, 137.2, 112.7,
#        230.9, 256.6, 110.4, 193.7, 123.2, 135.5, 113.1, 196.6, 115.6,
#        196.7, 115.9, 256.7, 108.6, 112.4, 110.2, 110.5, 124.7, 190.1])

# %%
data[['OS','3.5mm jack']].value_counts()
# Out:
# OS       3.5mm jack
# Android  True          2192
#          False          257
# Windows  True            65
# Others   True            53
# iOS      False           33
#          True            32
# Others   False           19
# Name: count, dtype: int64

# %%
data[['OS','Loudspeaker']].value_counts()
# Out:
# OS       Loudspeaker
# Android  True           1871
#          False           578
# Windows  True             58
# Others   True             55
# iOS      False            49
# Others   False            17
# iOS      True             16
# Windows  False             7
# Name: count, dtype: int64

# %%
data[['OS','Sensors']].value_counts()
# Out:
# OS       Sensors
# Android  Accelerometer, proximity, compass                                                                                                          376
#          Accelerometer, proximity                                                                                                                   333
#          Accelerometer, gyro, proximity, compass                                                                                                    281
#          Fingerprint (rear-mounted), accelerometer, gyro, proximity, compass                                                                        181
#          Accelerometer                                                                                                                              163
#          Fingerprint (under display, optical), accelerometer, gyro, proximity, compass                                                              109
#          Fingerprint (rear-mounted), accelerometer, proximity                                                                                        96
#          Fingerprint (side-mounted), accelerometer, gyro, proximity, compass                                                                         94
#          Fingerprint (rear-mounted), accelerometer, proximity, compass                                                                               92
#          Fingerprint (front-mounted), accelerometer, gyro, proximity, compass                                                                        60
#          Fingerprint (side-mounted), accelerometer, proximity, compass                                                                               44
#          Accelerometer, gyro, proximity, compass, barometer                                                                                          39
#          Accelerometer, gyro, compass                                                                                                                33
#          Fingerprint (side-mounted), accelerometer, gyro, compass                                                                                    30
#          Fingerprint (under display, ultrasonic), accelerometer, gyro, proximity, compass, barometer                                                 28
#          Accelerometer, compass                                                                                                                      28
#          Fingerprint (under display, optical), accelerometer, gyro, compass                                                                          27
# Windows  Accelerometer, proximity, compass                                                                                                           25
# Android  Fingerprint (side-mounted), accelerometer, proximity                                                                                        24
# iOS      Face ID, accelerometer, gyro, proximity, compass, barometer                                                                                 23
# Android  Fingerprint (under display, optical), accelerometer, gyro, proximity, compass, color spectrum                                               19
#          Accelerometer, gyro, proximity                                                                                                              18
#          Fingerprint (front-mounted), accelerometer, gyro, proximity, compass, barometer, heart rate, SpO2                                           16
# Others   Accelerometer, proximity                                                                                                                    16
# Android  Fingerprint (side-mounted), accelerometer, gyro, proximity, barometer, compass, color spectrum                                              16
#          Fingerprint (side-mounted), accelerometer, gyro, proximity, compass, barometer                                                              15
#          Fingerprint (front-mounted), accelerometer, proximity, compass                                                                              14
# Others   Accelerometer, proximity, compass                                                                                                           14
# Android  Fingerprint (rear-mounted), accelerometer, gyro, proximity                                                                                  14
#          Fingerprint (rear-mounted), accelerometer, gyro, proximity, compass, barometer                                                              13
# Windows  Accelerometer, gyro, proximity, compass                                                                                                     13
# Android  Fingerprint (side-mounted), accelerometer                                                                                                   12
# iOS      Fingerprint (front-mounted), accelerometer, gyro, compass, barometer                                                                        12
# Windows  Accelerometer, proximity                                                                                                                    12
# Android  Fingerprint (front-mounted), accelerometer, gyro, proximity, compass, barometer                                                             11
#          Fingerprint (rear-mounted), accelerometer                                                                                                   11
#          Fingerprint (side-mounted), accelerometer, compass                                                                                           8
#          Accelerometer, gyro, proximity, compass, barometer, temperature, humidity, gesture                                                           8
# iOS      Fingerprint (front-mounted), accelerometer, gyro, proximity, compass, barometer                                                              8
# Others   Accelerometer                                                                                                                                7
# iOS      Accelerometer, gyro, compass                                                                                                                 7
# Android  Fingerprint (front-mounted), accelerometer, gyro, proximity, compass, barometer, gesture, heart rate                                         7
#          Fingerprint (rear-mounted), accelerometer, gyro, proximity, compass, barometer, color spectrum                                               7
#          Fingerprint (rear-mounted), accelerometer, gyro, proximity, barometer, compass                                                               7
#          Fingerprint (front-mounted), accelerometer, proximity                                                                                        6
#          Fingerprint (under display, optical), accelerometer, gyro, proximity, compass, barometer                                                     6
#          Face ID, fingerprint (under display, optical), accelerometer, gyro, proximity, barometer, compass                                            6
#          Iris scanner, fingerprint (rear-mounted), accelerometer, gyro, proximity, compass, barometer, heart rate, SpO2                               6
#          Fingerprint (side-mounted), accelerometer, gyro, proximity                                                                                   6
#          Fingerprint (rear-mounted), accelerometer, gyro, compass                                                                                     6
# Others   Fingerprint (side-mounted), accelerometer, proximity, compass                                                                                6
# Android  Fingerprint (side-mounted), accelerometer, gyro, compass, color spectrum                                                                     5
# iOS      Accelerometer, gyro, proximity, compass                                                                                                      5
# Android  Fingerprint (side-mounted), accelerometer, gyro, proximity, compass, color spectrum                                                          5
#          Yes                                                                                                                                          5
# Others   Face ID, fingerprint (under display, optical), accelerometer, gyro, proximity, barometer, compass, color spectrum                            5
# Android  Fingerprint (under display, optical), accelerometer, gyro, compass, barometer                                                                4
#          Fingerprint (rear-mounted), accelerometer, gyro, proximity, barometer, compass, color spectrum                                               4
#          Fingerprint (under display, optical), accelerometer, proximity, compass                                                                      4
#          Fingerprint (side-mounted), accelerometer, gyro, proximity, compass, color spectrum, barometer                                               4
#          Face ID, fingerprint (under display, optical), accelerometer, gyro, proximity, barometer, compass, color spectrum                            4
#          Fingerprint (front-mounted), accelerometer, gyro, proximity, compass, heart rate                                                             4
# Windows  Accelerometer, gyro, proximity, compass, sensor core                                                                                         4
# Android  Fingerprint (front-mounted), accelerometer, gyro, compass                                                                                    4
#          Iris scanner, fingerprint (front-mounted), accelerometer, gyro, proximity, compass, barometer, heart rate, SpO2                              3
#          Accelerometer, gyro                                                                                                                          3
# Windows  Accelerometer, sensor core                                                                                                                   3
#          Accelerometer, gyro, proximity, compass, barometer                                                                                           3
# Android  Fingerprint (side-mounted), accelerometer, proximity, gyro, compass                                                                          3
# Windows  Accelerometer                                                                                                                                3
# Android  Fingerprint (side-mounted; EU model only), accelerometer, gyro, proximity, compass, barometer                                                3
# Others   Accelerometer, gyro, proximity, compass                                                                                                      3
# Android  Fingerprint (under display, optical), accelerometer, proximity, gyro, compass, barometer, color spectrum                                     3
#          Fingerprint (front-mounted), accelerometer, gyro, proximity, compass, barometer, gesture, UV, heart rate, SpO2                               3
#          Fingerprint (front-mounted), accelerometer, gyro, proximity, barometer, compass                                                              3
#          Infrared Face ID, fingerprint (rear-mounted), accelerometer, gyro, proximity, compass                                                        3
#          Fingerprint (under display, optical), accelerometer, proximity, gyro, compass, color spectrum                                                3
#          Fingerprint (front-mounted), accelerometer, gyro, proximity, compass, color spectrum                                                         3
#          Fingerprint (under display, optical), accelerometer, gyro, compass, color spectrum                                                           3
# iOS      Fingerprint (front-mounted), accelerometer, gyro, proximity, compass                                                                         2
#          Face ID, accelerometer, gyro, proximity, barometer                                                                                           2
#          Face ID, accelerometer, gyro, barometer                                                                                                      2
# Android  Fingerprint (under display, ultrasonic), accelerometer, gyro, proximity, compass, barometer, heart rate, SpO2                                2
#          Iris scanner, fingerprint (rear-mounted), accelerometer, gyro, proximity, compass                                                            2
#          Fingerprint (under display, optical), accelerometer, gyro, proximity, compass, heart rate                                                    2
#          Fingerprint (side-mounted), unspecified sensors                                                                                              2
#          Fingerprint (side-mounted, region dependent), accelerometer, gyro, proximity, barometer, compass, color spectrum                             2
#          Infrared Face ID, fingerprint (under display, optical), accelerometer, gyro, proximity, compass                                              2
# Others   Fingerprint (under display, optical), accelerometer, gyro, proximity, compass                                                                2
# Android  Infrared Face ID, fingerprint (under display, optical), accelerometer, gyro, proximity, compass, color spectrum                              2
#          Fingerprint (under display, optical), accelerometer, proximity, gyro, compass                                                                2
#          Fingerprint (side-mounted), accelerometer, gyro, proximity, barometer, compass                                                               2
# iOS      Fingerprint (front-mounted), accelerometer, proximity, gyro, compass, barometer                                                              2
# Android  Accelerometer, gyro, proximity, compass (LTE model only)                                                                                     2
#          Dual fingerprint (side-mounted), accelerometer, gyro, proximity, compass                                                                     2
#          Fingerprint (side-mounted), accelerometer, gyro, proximity, compass, barometer (China only)                                                  2
#          Accelerometer, proximity, compass, color spectrum                                                                                            2
#          Fingerprint (front-mounted), accelerometer, gyro, proximity, compass, heart rate, altimeter                                                  2
#          Accelerometer, proximity, barometer                                                                                                          2
#          Accelerometer, gyro, proximity, compass, barometer, heart rate                                                                               2
#          Accelerometer, gyro, proximity, compass, barometer, gesture                                                                                  2
#          Accelerometer, gyro, proximity, compass, heart rate                                                                                          2
#          Accelerometer, proximity, gyro                                                                                                               2
#          Fingerprint (side-mounted), accelerometer, gyro, compass, proximity (accessories only)                                                       2
#          Fingerprint (side-mounted), accelerometer, gyro, compass, barometer                                                                          2
#          Accelerometer, gyro, compass, proximity (accessories only)                                                                                   2
# Others   Fingerprint (side-mounted), gyro, accelerometer, proximity, compass, barometer, color spectrum                                               1
# Android  Accelerometer, compass, proximity                                                                                                            1
#          Accelerometer, compass, proximity (3G/LTE models only)                                                                                       1
# Others   Accelerometer, gyro, proximity, compass, barometer                                                                                           1
# Android  Accelerometer, proximity, compass, gyro (5G model only)                                                                                      1
#          Accelerometer, proximity, compass (optional)                                                                                                 1
# Others   Fingerprint (rear-mounted), accelerometer, proximity                                                                                         1
#          Fingerprint (side-mounted), accelerometer, compass                                                                                           1
#          Fingerprint (side-mounted), accelerometer, gyro, compass, proximity (ultrasound)                                                             1
#          Fingerprint (side-mounted), accelerometer, gyro, proximity, compass                                                                          1
#          Fingerprint (side-mounted), accelerometer, gyro, proximity, compass, barometer, color spectrum                                               1
# Android  Accelerometer, proximity, compass (7041X, 7041D only)                                                                                        1
#          Accelerometer, gyro, proximity (accessories only)                                                                                            1
#          Accelerometer, gyro (optional), proximity                                                                                                    1
# iOS      Fingerprint (front-mounted), accelerometer, gyro, compass                                                                                    1
# Others   Fingerprint (under display, optical), accelerometer, proximity, compass                                                                      1
# Android  Accelerometer, proximity (LTE model only)                                                                                                    1
#          Accelerometer, gyro, proximity, compass, temperature                                                                                         1
# Others   Accelerometer, gyro, compass, proximity (accessories only)                                                                                   1
# Android  Accelerometer, gyro, proximity, compass, color spectrum                                                                                      1
#          Accelerometer, gyro, compass, barometer                                                                                                      1
# Windows  Accelerometer, proximity, compass, sensor core                                                                                               1
# Android  Accelerometer, gyro, proximity, compass, barometer, color spectrum                                                                           1
# Windows  Fingerprint (rear-mounted), accelerometer, gyro, proximity, compass                                                                          1
# iOS      Accelerometer, compass                                                                                                                       1
# Android  Accelerometer, gyro, proximity, compass, barometer (C6502 only)                                                                              1
# Others   Fingerprint (under display, optical), accelerometer, gyro, compass                                                                           1
# Android  Fingerprint (side-mounted), accelerometer, gyro, proximity, compass, barometer (USA only)                                                    1
#          Accelerometer, proximity, gyro (Bach-L09 only)                                                                                               1
#          Fingerprint (under display, optical), accelerometer, gyro, compass, barometer (USA only)                                                     1
#          Fingerprint (under display, optical), accelerometer, gyro, proximity, compass, color spectrum, barometer                                     1
#          Fingerprint (rear-mounted), proximity, gyro                                                                                                  1
#          Fingerprint (rear-mounted, 32/3GB only), accelerometer, proximity                                                                            1
#          Fingerprint (rear-mounted, 5008T only), accelerometer, proximity                                                                             1
#          Fingerprint (rear-mounted, 5059A/J only), accelerometer, proximity                                                                           1
#          Fingerprint (under display, optical), accelerometer, gyro, compass, barometer, color spectrum                                                1
#          Fingerprint (rear-mounted; region dependent), accelerometer, proximity, compass                                                              1
#          Fingerprint (rear-mounted), accelerometer, proximity, compass, gyroscope, ambient light sensor                                               1
#          Fingerprint (side-mounted), accelerometer, gyro                                                                                              1
#          Fingerprint (under display, optical) - market dependant, accelerometer, proximity                                                            1
#          Fingerprint (side-mounted), accelerometer, gyro, compass, barometer (USA only)                                                               1
#          Fingerprint (side-mounted), accelerometer, gyro, compass, barometer, color spectrum                                                          1
#          Fingerprint (side-mounted), accelerometer, gyro, proximity, compass - North AmericaAccelerometer, proximity - other markets                  1
#          Fingerprint (side-mounted), accelerometer, proximity (8704X/8704N only)                                                                      1
#          Fingerprint (rear-mounted), accelerometer, proximity, gyro                                                                                   1
#          Fingerprint (under display, optical), accelerometer, proximity, compass, gyro                                                                1
#          Face ID, Hand ID, fingerprint (rear-mounted), accelerometer, gyro, proximity, compass, barometer                                             1
#          Fingerprint (front-mounted), accelerometer                                                                                                   1
#          Iris scanner, fingerprint (rear-mounted), accelerometer, gyro, proximity, compass, barometer, heart rate                                     1
#          Iris scanner, fingerprint (rear-mounted), accelerometer, gyro, proximity, compass, barometer                                                 1
#          Face ID, fingerprint (under display, optical), accelerometer, gyro, proximity, barometer, compass, infrared thermometer, color spectrum      1
#          Face recognition, accelerometer, gyro                                                                                                        1
#          Iris scanner, accelerometer, gyro, proximity, compass                                                                                        1
#          Fingerprint (Exclusive edition only; side-mounted), accelerometer, gyro, proximity, compass                                                  1
#          Infrared Face ID, fingerprint (rear-mounted), accelerometer, proximity, compass                                                              1
#          Fingerprint (rear-mounted), accelerometer, gyro, compass, barometer                                                                          1
#          Fingerprint (front-mounted), accelerometer, gyro, proximity, compass, barometer, UV, heart rate, SpO2                                        1
#          Fingerprints (rear-mounted and under display, optical), accelerometer, gyro, proximity, compass, barometer                                   1
#          Fingerprint (front-mounted), accelerometer, proximity, gyro, compass, proximity (accessories only)                                           1
#          Fingerprint (under display, ultrasonic), accelerometer, gyro, proximity, compass                                                             1
#          Fingerprint (rear-mounted), accelerometer, gyro (except LX2, AL00), proximity, compass                                                       1
#          Fingerprint (rear-mounted), accelerometer, gyro (market dependent), proximity, compass                                                       1
#          Unspecified                                                                                                                                  1
# Name: count, dtype: int64

# %%
data[["OS","Display Type"]].value_counts()
# Out:
# OS       Display Type
# Android  IPS LCD                                                                                               991
#          TFT                                                                                                   222
#          Super AMOLED                                                                                          201
#          TFT, 256K colors                                                                                       80
#          PLS LCD                                                                                                57
#          IPS LCD, 400 nits (typ)                                                                                40
#          AMOLED                                                                                                 36
# iOS      IPS LCD                                                                                                28
# Android  TFT LCD                                                                                                25
#          IPS LCD, 90Hz                                                                                          24
#          IPS LCD,                                                                                               22
#          Super LCD3                                                                                             21
#          Super LCD2                                                                                             20
#          OLED, HDR10                                                                                            19
#          Super AMOLED Plus                                                                                      18
#          S-LCD                                                                                                  18
#          IPS LCD, HDR10                                                                                         18
#          Super AMOLED, HDR10                                                                                    18
#          OLED                                                                                                   16
# Windows  IPS LCD                                                                                                16
# Android  Super LCD                                                                                              16
#          LED-backlit LCD,                                                                                       15
#          LCD                                                                                                    14
# Windows  AMOLED                                                                                                 13
#          TFT                                                                                                    11
# Others   TFT, 256K colors                                                                                       11
# Android  IPS LCD, 450 nits (typ)                                                                                10
#          S-IPS LCD                                                                                              10
#          LED-backlit IPS LCD                                                                                     9
#          True HD-IPS + LCD                                                                                       9
# Others   AMOLED                                                                                                  9
#          IPS LCD                                                                                                 9
# Android  Super IPS+ LCD                                                                                          8
#          Dynamic AMOLED, HDR10+                                                                                  8
# iOS      Super Retina XDR OLED, HDR10, Dolby Vision, 800 nits (HBM), 1200 nits (peak)                            8
# Android  HD-IPS LCD                                                                                              7
#          True HD-IPS LCD                                                                                         7
#          IPS LCD, 90Hz, 400 nits (typ)                                                                           7
#          PLS LCD, 90Hz                                                                                           7
# Others   TFT                                                                                                     7
# Android  Super clear LCD                                                                                         7
#          Super AMOLED, 420 nits (peak)                                                                           7
#          TFT,  256K colors                                                                                       7
# iOS      Retina IPS LCD, 625 nits (typ)                                                                          6
# Windows  S-LCD                                                                                                   6
# Android  IPS LCD, 120Hz, HDR10, 450 nits (typ)                                                                   6
#          Super AMOLED, 120Hz, HDR10+                                                                             6
#          Super AMOLED, 120Hz, 700 nits, 1200 nits (peak)                                                         6
#          Super AMOLED, HDR                                                                                       6
#          IPS+ LCD                                                                                                6
#          OLED, 1B colors, 120Hz, HDR BT.2020                                                                     6
# Windows  Super AMOLED                                                                                            6
# Android  Dynamic AMOLED 2X, 120Hz, HDR10+                                                                        6
#          IPS-NEO LCD                                                                                             5
#          AMOLED, 90Hz                                                                                            5
#          Dynamic AMOLED 2X, 120Hz, HDR10+, 1200 nits (peak)                                                      5
#          TFT, 65K colors                                                                                         5
# Others   TFT resistive touchscreen, 16M colors                                                                   5
# Android  LCD, 90Hz                                                                                               5
#          TFT LCD, 120Hz                                                                                          5
#          Super IPS LCD2                                                                                          5
#          P-OLED, HDR10                                                                                           5
#          AMOLED, 1B colors, 120Hz, HDR10+, 1500 nits (peak)                                                      5
#          Super AMOLED, 90Hz, 800 nits (HBM)                                                                      5
#          PLS                                                                                                     4
#          IPS LCD, 120Hz, HDR10                                                                                   4
#          AMOLED, HDR10, 600 nits (typ)                                                                           4
#          IPS LCD, 256K colors                                                                                    4
#          Super LCD5                                                                                              4
# iOS      LTPO Super Retina XDR OLED, 120Hz, HDR10, Dolby Vision, 1000 nits (typ), 2000 nits (HBM)                4
# Android  TFT resistive touchscreen, 256K colors                                                                  4
#          OLED, 1B colors, HDR                                                                                    4
#          3D LCD                                                                                                  4
#          Super AMOLED, 144Hz, HDR10+, 1300 nits (peak)                                                           4
#          Dynamic LTPO AMOLED 2X, 120Hz, HDR10+, 2600 nits (peak)                                                 3
#          Dynamic AMOLED 2X, 120Hz, HDR10+, 1200 nits (HBM), 1750 nits (peak)                                     3
#          Dynamic AMOLED 2X, 120Hz, HDR10+, 1300 nits (peak)                                                      3
# iOS      IPS LCD, 120Hz                                                                                          3
# Android  AMOLED, 144Hz                                                                                           3
# iOS      Super Retina OLED, HDR10, Dolby Vision, 625 nits (HBM)                                                  3
# Android  Super AMOLED, 120Hz, HDR10+, 1300 nits (peak)                                                           3
#          IPS LCD, 90Hz, 400 nits (typ), 500 nits (HBM)                                                           3
#          IPS LCD, 90Hz, 450 nits (typ), 600 nits (HBM)                                                           3
#          IPS LCD, 90Hz, 500 nits (peak)                                                                          3
#          Super AMOLED, HDR10+, 500 nits (typ)                                                                    3
#          IPS+ LCD,                                                                                               3
#          OLED, 120Hz, Dolby Vision, HDR10+, 1200 nits (peak)                                                     3
# Windows  TFT, 65K colors                                                                                         3
# Android  OLED, HDR10, 90Hz                                                                                       3
#          OLED, 1B colors, 120Hz, Dolby Vision, HDR10+, 500 nits (typ), 900 nits (HBM)                            3
#          SC-LCD                                                                                                  3
#          AMOLED, 1B colors, 144Hz, HDR10+, 1000 nits                                                             3
#          Super AMOLED Plus, HDR10+                                                                               3
# Others   TFT LCD                                                                                                 3
# Android  AMOLED, 68B colors, 120Hz, Dolby Vision, HDR10+, 1100 nits (peak)                                       3
#          AMOLED, 90Hz, 700 nits, 1000 nits (peak)                                                                3
#          Super AMOLED Plus, 120Hz                                                                                3
#          AMOLED, 1B colors (China only), 120Hz, 1300 nits (peak)                                                 3
# Others   TN TFT LCD                                                                                              3
# Android  OLED, 68B colors, 120Hz, Dolby Vision, HDR10+, 1400 nits (peak)                                         2
# Others   OLED                                                                                                    2
# Android  IPS LCD, HDR BT.2020                                                                                    2
#          IPS LCD, 540 nits (typ)                                                                                 2
#          OLED, 1B colors, HDR10, 90Hz                                                                            2
#          AMOLED, 1B colors, 144Hz, HDR10+, 650 nits (typ)                                                        2
#          IPS LCD, 90Hz, 500 nits (HBM)                                                                           2
# iOS      Super Retina XDR OLED, HDR10, Dolby Vision, 625 nits (HBM), 1200 nits (peak)                            2
# Android  IPS LCD, 90Hz, 450 nits (typ)                                                                           2
# Others   OLED, 1B colors, 90Hz                                                                                   2
# Android  IPS LCD, HDR10, 120Hz, 450 nits (typ)                                                                   2
# Others   OLED, 1B colors, 120Hz, HDR10                                                                           2
# iOS      Super Retina XDR OLED, HDR10, Dolby Vision, 1000 nits (HBM), 2000 nits (peak)                           2
# Others   OLED, 1B colors, 120Hz                                                                                  2
# Android  OLED, 1B colors, HDR BT.2020                                                                            2
#          AMOLED, 1B colors, 144Hz, HDR10+                                                                        2
#          IPS LCD, HDR10, 450 nits (typ)                                                                          2
#          Super AMOLED, HDR, 430 nits (typ)                                                                       2
#          AMOLED, 1B colors, 120Hz, 900 nits (peak)                                                               2
#          Super AMOLED, 90Hz, 600 nits (HDR)                                                                      2
#          AMOLED, 1B colors, 120Hz, Dolby Vision, HDR10+, 500 nits (typ), 900 nits (HBM)                          2
# Windows  S-LCD2                                                                                                  2
# Android  Super AMOLED, 90Hz, HDR10+, 500 nits (typ)                                                              2
#          LTPO AMOLED, 1B colors, 165Hz, HDR10, 1600 nits (HBM), 2500 nits (peak)                                 2
#          Super AMOLED, 120Hz, HDR10, 450 nits (typ), 1200 nits (peak)                                            2
#          LTPO AMOLED, 1B colors, 120Hz, Dolby Vision, HDR10+, 1000 nits (HBM), 1500 nits (peak)                  2
#          OLED, 1B colors, Dolby Vision, HDR10+, 120Hz, 950 nits (peak)                                           2
#          AMOLED, 120Hz                                                                                           2
# Others   TFT, 16M colors                                                                                         2
#          TFT LCD, 16M colors                                                                                     2
# iOS      Liquid Retina XDR mini-LED LCD, 120Hz, HDR10, Dolby Vision, 1000 nits (typ), 1600 nits (peak)           2
# Others   Super AMOLED                                                                                            2
# Android  IPS LCD, 500 nits                                                                                       2
#          IPS LCD, 500 nits (typ)                                                                                 2
#          Curved P-OLED                                                                                           2
# Others   Foldable OLED, 1B colors, 120Hz                                                                         2
# Android  IPS LCD, 144Hz, HDR10+, 500 nits (typ), 650 nits (peak)                                                 2
#          AMOLED, 1B colors (China only), 120Hz, 600 nits                                                         2
#          PLS LCD, 120Hz                                                                                          2
#          AMOLED, 144Hz, 1300 nits (peak)                                                                         2
#          AMOLED, 68B colors, 144Hz, Dolby Vision, HDR10+, 1200 nits (HBM), 2600 nits (peak)                      2
#          AMOLED, 68B colors, Dolby Vision, HDR10+, 120Hz, 500 nits (typ), 1000 nits (peak)                       2
#          IPS LCD, 120Hz                                                                                          2
# Windows  Super LCD3                                                                                              2
# Android  Super AMOLED, 120Hz, 800 nits (HBM)                                                                     2
#          IGZO IPS LCD                                                                                            2
# iOS      Super Retina XDR OLED, 120Hz, HDR10, Dolby Vision, 1000 nits (HBM), 1200 nits (peak)                    2
# Android  AMOLED, 90Hz, HDR10+, 500 nits (typ)                                                                    2
#          AMOLED, 165Hz, 700 nits (typ)                                                                           2
#          Dynamic AMOLED 2X, 120Hz, HDR10+, 1750 nits (peak)                                                      2
#          TFT LCD, 90Hz                                                                                           2
#          True Full HD IPS Plus LCD                                                                               2
#          Dynamic AMOLED 2X, 120Hz, HDR10+, 1400 nits (peak)                                                      2
#          P-OLED, HDR10, Dolby Vision                                                                             2
#          AMOLED, HDR10                                                                                           2
#          AMOLED, HDR10+, 600 nits (typ)                                                                          2
#          IPS LCD, 480 nits (typ)                                                                                 2
#          IPS LCD, 500 nits (peak)                                                                                2
#          OLED, 68B colors, 120Hz, Dolby Vision, HDR10+, 4000 nits (peak)                                         2
#          AMOLED, 120Hz, HDR10+, 1300 nits (peak)                                                                 2
#          OLED, HDR BT.2020                                                                                       2
#          Super IPS+                                                                                              2
#          Super AMOLED, 120Hz, 1000 nits (HBM)                                                                    2
# Windows  OLED                                                                                                    2
# Android  IPS LCD, 470 nits (typ)                                                                                 2
#          AMOLED, 68B colors, 120Hz, Dolby Vision, 500 nits (typ), 1200 nits (HBM), 1800 nits (peak)              2
# Others   LTPO OLED, 1B colors, 120Hz                                                                             2
# Android  IPS LCD, 330 nits (typ)                                                                                 2
#          IPS LCD, 350 nits (typ)                                                                                 2
#          AMOLED, 1B colors (China only), 165Hz, 700 nits (typ)                                                   2
#          AMOLED, 120Hz, HDR10+, 500 nits (typ)                                                                   2
#          Super AMOLED, 120Hz, HDR10                                                                              1
#          Super AMOLED, 120Hz, HDR10, 700 nits (HBM), 1200 nits (peak)                                            1
#          Super AMOLED, 144Hz, HDR10+, 800 nits (HBM), 1100 nits (peak)                                           1
#          Super AMOLED, 120Hz, HDR10+, 1100 nits (peak)                                                           1
#          Super AMOLED, 120Hz, HDR10+, 700 nits (HBM), 1100 nits (peak)                                           1
#          Super AMOLED Plus, 420 nits (peak)                                                                      1
#          Super AMOLED, 120Hz, HDR10+, 800 nits (HBM)                                                             1
#          Super AMOLED, 120Hz, HDR10+, 1000 nits (HBM)                                                            1
#          Super AMOLED, 120Hz, HDR10+, 900 nits (HBM), 1300 nits (peak)                                           1
#          Super AMOLED, 120Hz, 700 nits (HBM), 1200 nits (peak)                                                   1
# Windows  LCD                                                                                                     1
# Android  Super AMOLED, 450 nits (typ), 1100 nits (peak)                                                          1
#          True IPS+ LCD                                                                                           1
# Windows  Super AMOLED Plus                                                                                       1
# Android  TFT LCD, 60Hz (International), 90Hz (SM-A326U, SM-326DL only)                                           1
#          TFT resistive touchscreen, 256K colors (65K effective)                                                  1
#          TFT,                                                                                                    1
#          TN                                                                                                      1
#          True HD IPS Plus                                                                                        1
#          True HD IPS+                                                                                            1
# Others   IPS LCD, 144Hz                                                                                          1
# Windows  TFT, 256K colors                                                                                        1
# Others   IPS LCD, 540 nits (typ)                                                                                 1
#          LED-backlit IPS LCD                                                                                     1
#          OLED, 1B colors, 120Hz, 600 nits (typ)                                                                  1
#          OLED, 1B colors, HDR10, 120Hz                                                                           1
#          OLED, HDR10, 90Hz                                                                                       1
#          TFT, 65K colors                                                                                         1
# Windows  AMOLED, 65K colors                                                                                      1
# Android  TFT LCD, 120Hz, HDR10+                                                                                  1
#          TDDI IPS LCD, 350 nits (typ)                                                                            1
#          Super AMOLED, 450 nits (typ), 700 nits (HBM), 1100 nits (peak)                                          1
#          Super AMOLED, HDR10+                                                                                    1
#          Super AMOLED, 90Hz                                                                                      1
#          Super AMOLED, 90Hz, 600 nits                                                                            1
#          Super AMOLED, 90Hz, HDR10+, 700 nits (HBM)                                                              1
# iOS      Retina IPS LCD, 500 nits (typ)                                                                          1
# Android  Super AMOLED, 90Hz, HDR10+, 700 nits (HBM), 1000 nits (peak)                                            1
# iOS      Liquid Retina IPS LCD, 625 nits (typ)                                                                   1
#          Liquid Retina IPS LCD, 625 nits (HBM)                                                                   1
# Android  Super AMOLED, HDR10+, 430 nits (typ)                                                                    1
#          TDDI                                                                                                    1
#          Super Clear LCD                                                                                         1
#          Super Flexible AMOLED                                                                                   1
#          Super IPS LCD                                                                                           1
# iOS      IPS LCD, 500 nits                                                                                       1
#          IPS LCD, 120Hz, 600 nits (typ)                                                                          1
# Android  Super LCD6                                                                                              1
#          Super LCD6, HDR10                                                                                       1
#          TFT  LCD                                                                                                1
#          3D IPS LCD                                                                                              1
#          Super AMOLED , 90Hz, HDR10+, 700 nits (HBM)                                                             1
#          AMOLED, 1B colors, 120Hz, HDR10+                                                                        1
#          AMOLED, 1B colors, 120Hz, HDR10+, 800 nits (typ), 1000 nits (peak)                                      1
#          AMOLED, 1B colors, 120Hz, HDR10+, Dolby Vision, 800 nits (HBM)                                          1
#          AMOLED, 1B colors, 120Hz, HDR10+, Dolby Vision, 900 nits (HBM), 1700 nits (peak)                        1
#          AMOLED, 1B colors, 144Hz, 1000 nits (peak)                                                              1
#          AMOLED, 1B colors, 144Hz, 770 nits (peak)                                                               1
#          AMOLED, 1B colors, 165Hz, 630 nits (typ)                                                                1
#          AMOLED, 1B colors, Dolby Vision, HDR10+, 120Hz, 1000 nits (peak)                                        1
#          AMOLED, 1B colors, Dolby Vision, HDR10+, 90Hz, 500 nits (typ), 800 nits (HBM)                           1
#          AMOLED, 1B colors, HDR10+, 90Hz, 500 nits (typ), 800 nits                                               1
#          AMOLED, 1B colors, HDR10, 90Hz, 500 nits (typ), 800 nits                                                1
#          AMOLED, 450 nits (typ), 1100 nits (peak)                                                                1
#          AMOLED, 450 nits (typ), 700 nits (HBM), 1100 nits (peak)                                                1
#          AMOLED, 650 nits (peak)                                                                                 1
#          AMOLED, 68B colors, 120Hz, Dolby Vision, HDR10+, 1500 nits (peak)                                       1
#          AMOLED, 68B colors, 120Hz, Dolby Vision, HDR10+, 1800 nits (peak)                                       1
#          AMOLED, 68B colors, 120Hz, Dolby Vision, HDR10+, 500 nits (typ), 1000 nits (HBM), 1400 nits (peak)      1
#          AMOLED, 68B colors, 120Hz, Dolby Vision, HDR10+, 500 nits (typ), 900 nits (peak)                        1
#          AMOLED, 68B colors, 120Hz, Dolby Vision, HDR10+, 950 nits (peak)                                        1
#          AMOLED, 68B colors, 120Hz, HDR10+, 500 nits (typ), 900 nits (peak)                                      1
#          AMOLED, 68B colors, 120Hz, HDR10+, Dolby Vision, 500 nits (typ), 1200 nits (HBM), 1800 nits (peak)      1
#          AMOLED, 770 nits (HBM)                                                                                  1
#          AMOLED, 90Hz, 450 nits (typ), 700 nits (peak)                                                           1
#          AMOLED, 90Hz, 700 nits (HBM), 1000 nits (peak)                                                          1
#          AMOLED, 90Hz, HDR                                                                                       1
#          AMOLED, 90Hz, HDR10+, 500 nits (typ), 1120 nits (peak)                                                  1
#          AMOLED, Dolby Vision, 1B colors, 120Hz, HDR10+, 800 nits (typ), 1000 nits (peak)                        1
#          AMOLED, HDR                                                                                             1
#          AMOLED, 1B colors, 120Hz, HDR10+, 800 nits (HBM)                                                        1
#          AMOLED, 1B colors, 120Hz, HDR10                                                                         1
#          Samsung AMOLED, 120Hz, 1200 nits (peak)                                                                 1
#          AMOLED, 1B colors, 120Hz, 950 nits (peak)                                                               1
#          3D S-LCD                                                                                                1
#          AH IPS LCD                                                                                              1
#          AH-IPS LCD                                                                                              1
#          AMOLED or LCD, 256K colors                                                                              1
#          AMOLED or SLCD                                                                                          1
#          AMOLED, 1000 nits (peak)                                                                                1
#          AMOLED, 120Hz, 1000 nits (HBM), 1300 nits (peak)                                                        1
#          AMOLED, 120Hz, 1200 nits (peak)                                                                         1
#          AMOLED, 120Hz, 1800 nits (peak)                                                                         1
#          AMOLED, 120Hz, 450 nits (typ), 700 nits (HBM), 1200 nits (peak)                                         1
#          AMOLED, 120Hz, 700 nits (peak)                                                                          1
#          AMOLED, 120Hz, 700 nits, 1200 nits (peak)                                                               1
#          AMOLED, 120Hz, 900 nits (HBM)                                                                           1
#          AMOLED, 120Hz, Dolby Vision, 700 nits (HBM), 1100 nits (peak)                                           1
#          AMOLED, 120Hz, Dolby Vision, HDR10+, 1200 nits (HBM), 1900 nits (peak)                                  1
#          AMOLED, 120Hz, HDR10+, Dolby Vision, 600 nits (HBM)                                                     1
#          AMOLED, 120Hz, HDR10, 450 nits (typ), 1200 nits (peak)                                                  1
#          AMOLED, 144Hz, HDR10+                                                                                   1
#          AMOLED, 144Hz, HDR10+, 800 nits (HBM)                                                                   1
#          AMOLED, 1B colors (China only), 120Hz, 1600 nits (peak)                                                 1
#          AMOLED, 1B colors*, 120Hz, 1000 nits (peak)                                                             1
#          AMOLED, 1B colors, 120Hz, 1000 nits (peak)                                                              1
#          AMOLED, 1B colors, 120Hz, 1200 nits (peak)                                                              1
#          AMOLED, 1B colors, 120Hz, 1300 nits (peak)                                                              1
#          AMOLED, 1B colors, 120Hz, 1600 nits (peak)                                                              1
#          AMOLED, 1B colors, 120Hz, 500 nits (typ), 1000 nits (HBM), 1300 nits (peak)                             1
#          AMOLED, 1B colors, 120Hz, 700 nits (peak)                                                               1
#          AMOLED, HDR10+, 430 nits (typ)                                                                          1
#          AMOLED, HDR10, 430 nits (typ)                                                                           1
#          Dual IPS LCD                                                                                            1
#          Dynamic AMOLED 2X, 120Hz, 1200 nits (peak)                                                              1
#          LTPO AMOLED, 1B colors, 120Hz, Dolby Vision, HDR10+, 1200 nits (HBM), 1900 nits (peak)                  1
#          LTPO AMOLED, 68B colors, 120Hz, Dolby Vision, HDR10+, 3000 nits (peak)                                  1
#          LTPO OLED, 68B colors, 120Hz, Dolby Vision, HDR10+, 3000 nits (peak)                                    1
#          OLED, 120Hz                                                                                             1
#          OLED, 120Hz, 1200 nits (peak)                                                                           1
#          OLED, 120Hz, HDR BT.2020                                                                                1
#          OLED, 144Hz, HDR10+, 1000 nits (peak)                                                                   1
#          OLED, 1B colors, 120Hz, 1000 nits (peak)                                                                1
#          OLED, 1B colors, 120Hz, HDR10+, 500 nits (typ)                                                          1
#          OLED, 1B colors, 120Hz, HDR10+, 800 nits (HBM)                                                          1
#          OLED, 1B colors, 120Hz, HDR10+, 800 nits (HBM), 1120 nits (peak)                                        1
#          OLED, 1B colors, 120Hz, HDR10, BT.2020                                                                  1
#          OLED, 1B colors, 144Hz, HDR10+                                                                          1
#          OLED, 1B colors, HDR10, 120Hz                                                                           1
#          OLED, 256K colors                                                                                       1
#          OLED, 600 nits (typ)                                                                                    1
#          OLED, 68B colors, 120Hz, Dolby Vision, HDR10+, 1000 nits (HBM)                                          1
#          OLED, 68B colors, 120Hz, Dolby Vision, HDR10+, 1800 nits (peak)                                         1
#          OLED, 68B colors, 144Hz, Dolby Vision, HDR10+, 2600 nits (peak)                                         1
#          OLED, 68B colors, 144Hz, HDR10+, Dolby Vision                                                           1
#          OLED, HDR10+, Dolby Vision, 120Hz, 420 nits (typ), 600 nits (peak)                                      1
#          OLED, HDR10, Dolby Vision, 500 nits (typ)                                                               1
#          P-OLED                                                                                                  1
#          P-OLED, HDR BT.2020                                                                                     1
#          PLS LCD, 90Hz, 400 nits (peak)                                                                          1
#          PLS LCD, 90Hz, 400 nits (typ)                                                                           1
#          S-LCD, 256K colors                                                                                      1
#          LCD, 550 nits (peak)                                                                                    1
#          IPS LCD, HDR10, Dolby Vision                                                                            1
#          IPS LCD, HDR10, 90Hz                                                                                    1
#          IPS LCD, 300 nits (typ)                                                                                 1
#          Dynamic AMOLED 2X, 120Hz, HDR10+, 1450 nits (peak)                                                      1
#          Dynamic AMOLED 2X, 120Hz, HDR10+, 1500 nits (peak)                                                      1
#          Foldable AMOLED, 1B colors, HDR10+, Dolby Vision, 600 nits (typ), 900 nits (peak)                       1
#          IPS LCD, 120Hz, 400 nits (typ)                                                                          1
#          IPS LCD, 120Hz, 450 nits (typ), 550 nits (HBM)                                                          1
#          IPS LCD, 120Hz, 500 nits                                                                                1
#          IPS LCD, 120Hz, Dolby Vision, HDR10, 500 nits (typ)                                                     1
#          IPS LCD, 144Hz, HDR10, 500 nits (typ), 650 nits (peak)                                                  1
#          IPS LCD, 1B colors, 120Hz                                                                               1
#          IPS LCD, 1B colors, 120Hz, HDR10, Dolby Vision                                                          1
#          IPS LCD, 1B colors, 144Hz, 600 nits (peak)                                                              1
#          IPS LCD, 270 nits (typ)                                                                                 1
#          IPS LCD, 320 nits (typ)                                                                                 1
#          IPS LCD, HDR, 500 nits (typ)                                                                            1
#          IPS LCD, 360 nits (typ)                                                                                 1
#          IPS LCD, 360 nits (typ), 450 nits (peak)                                                                1
#          IPS LCD, 400 nits                                                                                       1
#          IPS LCD, 440 nits (typ)                                                                                 1
#          IPS LCD, 480 nits                                                                                       1
#          IPS LCD, 550 nits                                                                                       1
#          IPS LCD, 550 nits (peak)                                                                                1
#          IPS LCD, 90Hz, 400 nits                                                                                 1
#          IPS LCD, 90Hz, 450 nits (typ), 560 nits (peak)                                                          1
#          IPS LCD, 90Hz, 500 nits (typ)                                                                           1
#          IPS LCD, Dolby Vision, 400 nits                                                                         1
#          IPS LCD, Dolby Vision, 400 nits (typ)                                                                   1
#          LTPO2 AMOLED, 1B colors, 120Hz, Dolby Vision, HDR10+, 1000 nits (HBM), 1500 nits (peak)                 1
# Name: count, dtype: int64

# %%
data[['OS','3G', '4G', '5G']].value_counts()
# Out:
# OS       3G     4G     5G
# Android  True   True   False    1510
#                 False  False     599
#                 True   True      322
# Windows  True   False  False      42
# iOS      True   True   False      40
# Others   True   True   False      32
#                 False  False      28
# Windows  True   True   False      22
# iOS      True   True   True       19
# Android  False  False  False       9
#                 True   False       9
# Others   False  False  False       8
# iOS      True   False  False       6
# Others   True   True   True        4
# Windows  False  False  False       1
# Name: count, dtype: int64

# %%
data['Network_Support'] = data['3G'].astype(int).astype(str) + data['4G'].astype(int).astype(str) + data['5G'].astype(int).astype(str)

# %%
feature_set1 = data.columns.drop(labels=['name','brand', '2G', '3G', '4G', '5G', 'OS', 'Display Type', '2G','Width', 'Diameter','CPU','ratio','WLAN', 'Colors', 'Sensors', 'Bluetooth', 'GPU', 'Chipset', 'Network', 'Internal','Version','pixel'])
feature_set1
# Out:
# Index(['Announced', 'Status', 'Weight', 'Length', 'SIM', 'Display Size', 'ppi',
#        'body ratio', 'battery_capacity', 'Price', 'Loudspeaker', '3.5mm jack',
#        'Card slot', 'RAM', 'Storage', 'n_colors', 'Network_Support'],
#       dtype='object')

# %%
data[feature_set1].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2651 entries, 0 to 4678
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Announced         2651 non-null   float64
#  1   Status            2651 non-null   object
#  2   Weight            2651 non-null   float64
#  3   Length            2651 non-null   float64
#  4   SIM               2651 non-null   object
#  5   Display Size      2651 non-null   float64
#  6   ppi               2651 non-null   float64
#  7   body ratio        2651 non-null   float64
#  8   battery_capacity  2651 non-null   float64
#  9   Price             2651 non-null   float64
#  10  Loudspeaker       2651 non-null   bool
#  11  3.5mm jack        2651 non-null   bool
#  12  Card slot         2651 non-null   object
#  13  RAM               2651 non-null   float64
#  14  Storage           2651 non-null   float64
#  15  n_colors          2651 non-null   int64
#  16  Network_Support   2651 non-null   object
# dtypes: bool(2), float64(10), int64(1), object(4)
# memory usage: 336.6+ KB

# %%
data['Length'] = data['Length'].astype('float64')
data['Announced'] = data['Announced'].astype('float64')
data['n_colors'] = data['n_colors'].astype('float64')

continuous_cols = []
categorical_cols = []

for col in feature_set1:
        if data[col].dtype == 'float64':
            continuous_cols.append(col)
        else:
            categorical_cols.append(col)

# %%
categorical_cols
# Out:
# ['Status', 'SIM', 'Loudspeaker', '3.5mm jack', 'Card slot', 'Network_Support']

# %%
continuous_cols
# Out:
# ['Announced',
#  'Weight',
#  'Length',
#  'Display Size',
#  'ppi',
#  'body ratio',
#  'battery_capacity',
#  'Price',
#  'RAM',
#  'Storage',
#  'n_colors']

# %% [markdown]
# Plots for engineered data

# %%
sns.countplot(data=data, x='OS')
# Out:
# <Axes: xlabel='OS', ylabel='count'>

# %%
plt.figure(figsize=(15, 10))

for i, col in enumerate(categorical_cols, 1):
    plt.subplot(3, 2, i)  
    sns.countplot(data=data, x=col, hue='OS')
    plt.title(f'Distribution of {col} by OS')
    plt.xticks(rotation=45)  

plt.tight_layout()
plt.show()

plt.figure(figsize=(15, 5))
sns.countplot(data=data, x='Announced', hue='OS')

plt.figure(figsize=(15, 5))
sns.countplot(data=data, x='n_colors', hue='OS')
# Out:
# <Axes: xlabel='n_colors', ylabel='count'>

# %%
plt.figure(figsize=(20, 15))

for i, col in enumerate(continuous_cols[1:], 1):
    plt.subplot(5,2 , i)  
    sns.boxplot(data=data, x='OS', y=col)
    plt.title(f'{col} Distribution by OS')

plt.tight_layout()
plt.show()

# %% [markdown]
# Dummify

# %%
categorical_cols_to_dummify = ['Status', 'SIM', 'Card slot', 'Network_Support']

cleaned_data = data[feature_set1]
# cleaned_data.loc[cleaned_data.Status == 'Coming','Status'] = 'Available'
dummies = pd.get_dummies(cleaned_data[categorical_cols_to_dummify])
cleaned_data = pd.concat([cleaned_data, dummies], axis=1)
cleaned_data.drop(categorical_cols_to_dummify, inplace = True, axis=1)

# %%
cleaned_data.columns
# Out:
# Index(['Announced', 'Weight', 'Length', 'Display Size', 'ppi', 'body ratio',
#        'battery_capacity', 'Price', 'Loudspeaker', '3.5mm jack', 'RAM',
#        'Storage', 'n_colors', 'Status_Available', 'Status_Discontinued',
#        'SIM_Micro-SIM', 'SIM_Mini-SIM', 'SIM_Nano-SIM', 'SIM_eSIM',
#        'Card slot_microsd', 'Card slot_microsdhc', 'Card slot_microsdxc',
#        'Card slot_nano memory', 'Card slot_no', 'Card slot_unspecified',
#        'Network_Support_000', 'Network_Support_010', 'Network_Support_100',
#        'Network_Support_110', 'Network_Support_111'],
#       dtype='object')

# %%
cleaned_data['3.5mm jack'] = cleaned_data['3.5mm jack'].astype('int32')
cleaned_data['Loudspeaker'] = cleaned_data['Loudspeaker'].astype('int32')
# cleaned_data['Network_Support'] = cleaned_data['Network_Support'].astype('int64')

# %%
continuous_cols = []
categorical_cols = []

for col in cleaned_data.columns:
        if cleaned_data[col].dtype == 'float64':
            continuous_cols.append(col)
        else:
            categorical_cols.append(col)

# %%
continuous_cols
# Out:
# ['Announced',
#  'Weight',
#  'Length',
#  'Display Size',
#  'ppi',
#  'body ratio',
#  'battery_capacity',
#  'Price',
#  'RAM',
#  'Storage',
#  'n_colors']

# %%
cleaned_data[continuous_cols].corr()
# Out:
#                   Announced    Weight    Length  Display Size       ppi  \
# Announced          1.000000  0.216229  0.403826      0.538291  0.408832
# Weight             0.216229  1.000000  0.929611      0.888796 -0.127769
# Length             0.403826  0.929611  1.000000      0.971983  0.027790
# Display Size       0.538291  0.888796  0.971983      1.000000  0.129369
# ppi                0.408832 -0.127769  0.027790      0.129369  1.000000
# body ratio         0.826368  0.252390  0.462303      0.623587  0.583282
# battery_capacity   0.631270  0.761959  0.842882      0.895648  0.223173
# Price              0.266497  0.320519  0.335055      0.397758  0.456231
# RAM                0.721997  0.220573  0.344843      0.478595  0.626512
# Storage            0.657078  0.183730  0.271642      0.398903  0.508886
# n_colors           0.175180 -0.146334 -0.081709     -0.029705  0.268301
#
#                   body ratio  battery_capacity     Price       RAM   Storage  \
# Announced           0.826368          0.631270  0.266497  0.721997  0.657078
# Weight              0.252390          0.761959  0.320519  0.220573  0.183730
# Length              0.462303          0.842882  0.335055  0.344843  0.271642
# Display Size        0.623587          0.895648  0.397758  0.478595  0.398903
# ppi                 0.583282          0.223173  0.456231  0.626512  0.508886
# body ratio          1.000000          0.664450  0.425506  0.774524  0.674999
# battery_capacity    0.664450          1.000000  0.392868  0.573253  0.495444
# Price               0.425506          0.392868  1.000000  0.638511  0.637402
# RAM                 0.774524          0.573253  0.638511  1.000000  0.888562
# Storage             0.674999          0.495444  0.637402  0.888562  1.000000
# n_colors            0.201173          0.002548  0.087734  0.174212  0.114713
#
#                   n_colors
# Announced         0.175180
# Weight           -0.146334
# Length           -0.081709
# Display Size     -0.029705
# ppi               0.268301
# body ratio        0.201173
# battery_capacity  0.002548
# Price             0.087734
# RAM               0.174212
# Storage           0.114713
# n_colors          1.000000

# %%
categorical_cols
# Out:
# ['Loudspeaker',
#  '3.5mm jack',
#  'Status_Available',
#  'Status_Discontinued',
#  'SIM_Micro-SIM',
#  'SIM_Mini-SIM',
#  'SIM_Nano-SIM',
#  'SIM_eSIM',
#  'Card slot_microsd',
#  'Card slot_microsdhc',
#  'Card slot_microsdxc',
#  'Card slot_nano memory',
#  'Card slot_no',
#  'Card slot_unspecified',
#  'Network_Support_000',
#  'Network_Support_010',
#  'Network_Support_100',
#  'Network_Support_110',
#  'Network_Support_111']

# %%
cleaned_data.head()
# Out:
#    Announced  Weight  Length  Display Size    ppi  body ratio  \
# 0     2022.0   172.0   146.7          5.50  293.0        74.0
# 1     2021.0   190.0   156.4          6.10  282.0        78.1
# 2     2021.0   134.0   137.6          5.00  215.0        71.4
# 3     2021.0   194.0   165.6          6.52  269.0        82.0
# 4     2021.0   190.0   165.6          6.52  269.0        82.0
#
#    battery_capacity  Price  Loudspeaker  3.5mm jack  RAM  Storage  n_colors  \
# 0            3000.0  100.0            1           1  2.0     32.0       2.0
# 1            3000.0  110.0            1           1  2.0     32.0       2.0
# 2            2000.0   60.0            1           1  1.0      8.0       2.0
# 3            4000.0  330.0            1           1  4.0     64.0       2.0
# 4            4000.0  130.0            1           1  3.0     32.0       2.0
#
#    Status_Available  Status_Discontinued  SIM_Micro-SIM  SIM_Mini-SIM  \
# 0              True                False          False         False
# 1              True                False          False         False
# 2              True                False          False         False
# 3              True                False          False         False
# 4              True                False          False         False
#
#    SIM_Nano-SIM  SIM_eSIM  Card slot_microsd  Card slot_microsdhc  \
# 0          True     False              False                False
# 1          True     False              False                False
# 2          True     False              False                 True
# 3          True     False              False                False
# 4          True     False              False                False
#
#    Card slot_microsdxc  Card slot_nano memory  Card slot_no  \
# 0                 True                  False         False
# 1                 True                  False         False
# 2                False                  False         False
# 3                 True                  False         False
# 4                 True                  False         False
#
#    Card slot_unspecified  Network_Support_000  Network_Support_010  \
# 0                  False                False                False
# 1                  False                False                False
# 2                  False                False                False
# 3                  False                False                False
# 4                  False                False                False
#
#    Network_Support_100  Network_Support_110  Network_Support_111
# 0                False                 True                False
# 1                False                 True                False
# 2                False                 True                False
# 3                False                 True                False
# 4                False                 True                False

# %% [markdown]
# Handling Outliers

# %%
outliers = IsolationForest(contamination=0.005, n_jobs=-1, random_state=45, bootstrap=True)

cls = outliers.fit_predict(cleaned_data)

# %%
data[cls== -1]['OS'].value_counts()
# Out:
# OS
# Android    8
# iOS        6
# Name: count, dtype: int64

# %%
data[cls==-1]
# Out:
#                                  name    brand    2G    3G     4G     5G  \
# 416        apple ipad pro 12 9 (2022)    apple  True  True   True   True
# 438        apple ipad pro 12 9 (2021)    apple  True  True   True   True
# 451        apple ipad pro 12 9 (2020)    apple  True  True   True  False
# 462        apple ipad pro 12 9 (2018)    apple  True  True   True  False
# 476        apple ipad pro 12 9 (2017)    apple  True  True   True  False
# 493        apple ipad pro 12 9 (2015)    apple  True  True   True  False
# 3848         samsung galaxy s24 ultra  samsung  True  True   True   True
# 3849              samsung galaxy s24+  samsung  True  True   True   True
# 3859        samsung galaxy tab s9 fe+  samsung  True  True   True   True
# 3866      samsung galaxy tab s9 ultra  samsung  True  True   True   True
# 3867           samsung galaxy tab s9+  samsung  True  True   True   True
# 3916      samsung galaxy tab s8 ultra  samsung  True  True   True   True
# 4303  samsung galaxy note pro 12 2 3g  samsung  True  True  False  False
# 4306   samsung galaxy tab pro 12 2 3g  samsung  True  True  False  False
#
#       Announced        Status  Weight  Length    Width Diameter        SIM  \
# 416      2022.0     Available   682.0  280.6    214.9      6.4        eSIM
# 438      2021.0     Available   682.0  280.6    214.9      6.4        eSIM
# 451      2020.0     Available   641.0  280.6    214.9      5.9        eSIM
# 462      2018.0     Available   631.0  280.6    214.9      5.9        eSIM
# 476      2017.0     Available   677.0  305.7    220.6      6.9        eSIM
# 493      2015.0  Discontinued   713.0  305.7    220.6      6.9        eSIM
# 3848     2024.0     Available   232.0  162.3       79      8.6        eSIM
# 3849     2024.0     Available   196.0  158.5     75.9      7.7        eSIM
# 3859     2023.0     Available   627.0  285.4    185.4      6.5        eSIM
# 3866     2023.0     Available   732.0  326.4    208.6      5.5        eSIM
# 3867     2023.0     Available   586.0  285.4    185.4      5.7        eSIM
# 3916     2022.0     Available   726.0  326.4    208.6      5.5    Nano-SIM
# 4303     2014.0  Discontinued   753.0  295.5      204        8   Micro-SIM
# 4306     2014.0  Discontinued   732.0  295.6      204        8   Micro-SIM
#
#                                            Display Type  Display Size    ppi  \
# 416   Liquid Retina XDR mini-LED LCD, 120Hz, HDR10, ...          12.9  265.0
# 438   Liquid Retina XDR mini-LED LCD, 120Hz, HDR10, ...          12.9  265.0
# 451                      IPS LCD, 120Hz, 600 nits (typ)          12.9  265.0
# 462                                      IPS LCD, 120Hz          12.9  265.0
# 476                                      IPS LCD, 120Hz          12.9  265.0
# 493                                             IPS LCD          12.9  264.0
# 3848  Dynamic LTPO AMOLED 2X, 120Hz, HDR10+, 2600 ni...           6.8  505.0
# 3849  Dynamic LTPO AMOLED 2X, 120Hz, HDR10+, 2600 ni...           6.7  513.0
# 3859                                      IPS LCD, 90Hz          12.4  243.0
# 3866                   Dynamic AMOLED 2X, 120Hz, HDR10+          14.6  239.0
# 3867                   Dynamic AMOLED 2X, 120Hz, HDR10+          12.4  266.0
# 3916                        Super AMOLED, 120Hz, HDR10+          14.6  240.0
# 4303                                    Super clear LCD          12.2  247.0
# 4306                                    Super clear LCD          12.2  247.0
#
#       body ratio       OS  battery_capacity    Price  CPU  ratio      pixel  \
# 416         85.4      iOS           10758.0  1450.00  8.0    4:3  5595136.0
# 438         85.4      iOS           10758.0  1200.00  8.0    4:3  5595136.0
# 451         85.4      iOS            9720.0  1000.00  8.0    4:3  5595136.0
# 462         85.4      iOS            9720.0  1100.00  8.0    4:3  5595136.0
# 476         76.4      iOS             891.0   900.00  6.0    4:3  5595136.0
# 493         77.0      iOS             307.0   850.00  2.0    4:3  5595136.0
# 3848        88.5  Android            5000.0  1299.00  NaN    5:9  4492800.0
# 3849        91.6  Android            4900.0  1024.92  NaN    5:9  4492800.0
# 3859        84.3  Android           10090.0   700.00  8.0  16:10  4096000.0
# 3866        90.7  Android           11200.0  1200.00  8.0  16:10  5470080.0
# 3867        84.3  Android           10090.0  1000.00  8.0  16:10  4905600.0
# 3916        90.0  Android           11200.0  1150.00  8.0  16:10  5470080.0
# 4303        71.6  Android            9500.0   640.00  8.0  16:10  4096000.0
# 4306        71.6  Android            9500.0   470.00  8.0  16:10  4096000.0
#
#                                                    WLAN  \
# 416      Wi-Fi 802.11 a/b/g/n/ac/6e, dual-band, hotspot
# 438       Wi-Fi 802.11 a/b/g/n/ac/6, dual-band, hotspot
# 451       Wi-Fi 802.11 a/b/g/n/ac/6, dual-band, hotspot
# 462         Wi-Fi 802.11 a/b/g/n/ac, dual-band, hotspot
# 476         Wi-Fi 802.11 a/b/g/n/ac, dual-band, hotspot
# 493         Wi-Fi 802.11 a/b/g/n/ac, dual-band, hotspot
# 3848  Wi-Fi 802.11 a/b/g/n/ac/6e/7, tri-band, Wi-Fi ...
# 3849  Wi-Fi 802.11 a/b/g/n/ac/6e, tri-band, Wi-Fi Di...
# 3859  Wi-Fi 802.11 a/b/g/n/ac/6, dual-band, Wi-Fi Di...
# 3866  Wi-Fi 802.11 a/b/g/n/ac/6e, tri-band, Wi-Fi Di...
# 3867  Wi-Fi 802.11 a/b/g/n/ac/6e, tri-band, Wi-Fi Di...
# 3916  Wi-Fi 802.11 a/b/g/n/ac/6e, dual-band, Wi-Fi D...
# 4303  Wi-Fi 802.11 a/b/g/n/ac, dual-band, Wi-Fi Dire...
# 4306  Wi-Fi 802.11 a/b/g/n/ac, dual-band, Wi-Fi Dire...
#
#                                                  Colors  \
# 416                                  Silver, Space Gray
# 438                                  Silver, Space Gray
# 451                                  Silver, Space Gray
# 462                                  Silver, Space Gray
# 476                            Space Gray, Gold, Silver
# 493                            Space Gray, Silver, Gold
# 3848  Titanium Black, Titanium Gray, Titanium Violet...
# 3849  Onyx Black, Marble Grey, Cobalt Violet, Amber ...
# 3859                       Mint, Silver, Gray, Lavender
# 3866                                    Beige, Graphite
# 3867                                    Beige, Graphite
# 3916                                           Graphite
# 4303                                       Black, White
# 4306                                              Black
#
#                                                 Sensors           Bluetooth  \
# 416             Face ID, accelerometer, gyro, barometer  5.3, A2DP, LE, EDR
# 438             Face ID, accelerometer, gyro, barometer  5.0, A2DP, LE, EDR
# 451   Face ID, accelerometer, gyro, proximity, barom...  5.0, A2DP, LE, EDR
# 462   Face ID, accelerometer, gyro, proximity, barom...  5.0, A2DP, LE, EDR
# 476   Fingerprint (front-mounted), accelerometer, gy...      4.2, A2DP, EDR
# 493   Fingerprint (front-mounted), accelerometer, gy...      4.0, A2DP, EDR
# 3848  Fingerprint (under display, ultrasonic), accel...       5.3, A2DP, LE
# 3849  Fingerprint (under display, ultrasonic), accel...       5.3, A2DP, LE
# 3859  Fingerprint (side-mounted), accelerometer, gyr...       5.3, A2DP, LE
# 3866  Fingerprint (under display, optical), accelero...       5.3, A2DP, LE
# 3867  Fingerprint (under display, optical), accelero...       5.3, A2DP, LE
# 3916  Fingerprint (under display, optical), accelero...       5.2, A2DP, LE
# 4303                       Accelerometer, gyro, compass           4.0, A2DP
# 4306                       Accelerometer, gyro, compass           4.0, A2DP
#
#                                                     GPU  Loudspeaker  \
# 416                        Apple GPU (10-core graphics)        False
# 438                         Apple GPU (8-core graphics)        False
# 451                         Apple GPU (8-core graphics)        False
# 462                         Apple GPU (7-core graphics)        False
# 476                 PowerVR Series 7 (12-core graphics)        False
# 493                 PowerVR Series 7 (12-core graphics)        False
# 3848                                 Adreno 750 (1 GHz)        False
# 3849  Adreno 750 (1 GHz) - USA/Canada/ChinaXclipse 9...        False
# 3859                                       Mali-G68 MP5        False
# 3866                                         Adreno 740        False
# 3867                                         Adreno 740        False
# 3916                                         Adreno 730        False
# 4303                                      Mali-T628 MP6        False
# 4306                                      Mali-T628 MP6        False
#
#       3.5mm jack                                            Chipset  \
# 416        False                                           Apple M2
# 438        False                                           Apple M1
# 451        False                                  Apple A12Z Bionic
# 462        False                           Apple A12X Bionic (7 nm)
# 476         True                          Apple A10X Fusion (10 nm)
# 493         True                                  Apple A9X (16 nm)
# 3848       False       Qualcomm SM8650-AC Snapdragon 8 Gen 3 (4 nm)
# 3849       False  Qualcomm SM8650-AC Snapdragon 8 Gen 3 (4 nm) -...
# 3859       False                                 Exynos 1380 (5 nm)
# 3866       False       Qualcomm SM8550-AC Snapdragon 8 Gen 2 (4 nm)
# 3867       False       Qualcomm SM8550-AC Snapdragon 8 Gen 2 (4 nm)
# 3916       False          Qualcomm SM8450 Snapdragon 8 Gen 1 (4 nm)
# 4303        True                           Exynos 5420 Octa (28 nm)
# 4306        True                           Exynos 5420 Octa (28 nm)
#
#                                                 Network  \
# 416               GSM / HSPA / LTE / 5G HSPA, LTE-A, 5G
# 438   GSM / CDMA / HSPA / EVDO / LTE / 5G HSPA, LTE-...
# 451   GSM / CDMA / HSPA / EVDO / LTE HSPA, LTE-A, EV...
# 462   GSM / CDMA / HSPA / EVDO / LTE HSPA 42.2/5.76 ...
# 476   GSM / CDMA / HSPA / EVDO / LTE HSPA 42.2/5.76 ...
# 493   GSM / CDMA / HSPA / EVDO / LTE HSPA 42.2/5.76 ...
# 3848  GSM / CDMA / HSPA / EVDO / LTE / 5G HSPA, LTE-...
# 3849  GSM / CDMA / HSPA / EVDO / LTE / 5G HSPA, LTE-...
# 3859         GSM / HSPA / LTE / 5G HSPA, LTE-A (CA), 5G
# 3866         GSM / HSPA / LTE / 5G HSPA, LTE-A (CA), 5G
# 3867         GSM / HSPA / LTE / 5G HSPA, LTE-A (CA), 5G
# 3916         GSM / HSPA / LTE / 5G HSPA, LTE-A (CA), 5G
# 4303                     GSM / HSPA HSPA 21.1/5.76 Mbps
# 4306                     GSM / HSPA HSPA 42.2/5.76 Mbps
#
#                                                Internal  Card slot   RAM  \
# 416   128GB 8GB RAM, 256GB 8GB RAM, 512GB 8GB RAM, 1...         no   8.0
# 438   128GB 8GB RAM, 256GB 8GB RAM, 512GB 8GB RAM, 1...         no   8.0
# 451   128GB 6GB RAM, 256GB 6GB RAM, 512GB 6GB RAM, 1...         no   6.0
# 462   64GB 4GB RAM, 256GB 4GB RAM, 512GB 4GB RAM, 1T...         no   4.0
# 476          64GB 4GB RAM, 256GB 4GB RAM, 512GB 4GB RAM         no   4.0
# 493          32GB 4GB RAM, 128GB 4GB RAM, 256GB 4GB RAM         no   4.0
# 3848       256GB 12GB RAM, 512GB 12GB RAM, 1TB 12GB RAM         no  12.0
# 3849                     256GB 12GB RAM, 512GB 12GB RAM         no  12.0
# 3859                      128GB 8GB RAM, 256GB 12GB RAM  microsdxc   8.0
# 3866  256GB 12GB RAM, 512GB 12GB RAM, 1TB 12GB RAM, ...  microsdxc  12.0
# 3867                     256GB 12GB RAM, 512GB 12GB RAM  microsdxc  12.0
# 3916  128GB 8GB RAM, 256GB 8GB RAM, 256GB 12GB RAM, ...  microsdxc   8.0
# 4303                         32GB 3GB RAM, 64GB 3GB RAM  microsdxc   3.0
# 4306                         32GB 3GB RAM, 64GB 3GB RAM  microsdxc   3.0
#
#       Storage Version Network_Support
# 416     128.0    16.1             111
# 438     128.0  14.5.1             111
# 451     128.0    13.4             110
# 462      64.0      12             110
# 476      64.0  10.3.2             110
# 493      32.0       9             110
# 3848    256.0      14             111
# 3849    256.0      14             111
# 3859    128.0      13             111
# 3866    256.0      13             111
# 3867    256.0      13             111
# 3916    128.0      12             111
# 4303     32.0     4.4             100
# 4306     32.0     4.4             100

# %% [markdown]
# Train-test split, scaling, oversampling

# %%
X = cleaned_data
y = data['OS']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

scaler = StandardScaler()
X_train_scaled = pd.DataFrame(scaler.fit_transform(X_train), columns = X_train.columns)
X_test_scaled = pd.DataFrame(scaler.transform(X_test), columns= X_test.columns)

categorical_indices = [X_train_scaled.columns.get_loc(col) for col in categorical_cols]

smote = SMOTENC(random_state=42, categorical_features = categorical_indices)
X_train_smote, y_train_smote = smote.fit_resample(X_train_scaled, y_train )

y_train_smote.value_counts()
# Out:
# OS
# Android    1958
# Windows    1958
# Others     1958
# iOS        1958
# Name: count, dtype: int64

# %%
X_train_scaled.head()
# Out:
#    Announced    Weight    Length  Display Size       ppi  body ratio  \
# 0  -0.162704 -0.366877  0.064425     -0.162485 -0.443789   -0.239226
# 1  -0.708483 -0.427052 -0.433233     -0.467070 -0.906603   -0.337954
# 2  -0.435593 -0.611656 -0.370634     -0.467070 -0.177917   -0.311028
# 3   0.928854 -0.315881  0.011216      0.270026  1.013583    1.017318
# 4  -1.800040 -0.774842 -1.597564     -1.563577 -1.300487   -1.872733
#
#    battery_capacity     Price  Loudspeaker  3.5mm jack       RAM   Storage  \
# 0         -0.420137 -0.009947      0.57154    0.356455 -0.358505 -0.512503
# 1         -0.844006 -0.797716      0.57154    0.356455 -0.763780 -0.719564
# 2         -0.722901 -0.377573      0.57154    0.356455 -0.358505 -0.512503
# 3          0.003731 -0.220019      0.57154    0.356455  0.452045  1.420067
# 4         -1.328427 -0.640163      0.57154    0.356455 -1.017077 -0.779957
#
#    n_colors  Status_Available  Status_Discontinued  SIM_Micro-SIM  \
# 0 -0.537310         -0.965683             0.965683      -0.567909
# 1 -1.240891         -0.965683             0.965683       1.760846
# 2  0.166271         -0.965683             0.965683      -0.567909
# 3  0.166271          1.035537            -1.035537      -0.567909
# 4  0.166271         -0.965683             0.965683      -0.567909
#
#    SIM_Mini-SIM  SIM_Nano-SIM  SIM_eSIM  Card slot_microsd  \
# 0     -0.462070      0.918411  -0.19803          -0.043478
# 1     -0.462070     -1.088837  -0.19803          -0.043478
# 2     -0.462070      0.918411  -0.19803          -0.043478
# 3     -0.462070      0.918411  -0.19803          -0.043478
# 4      2.164173     -1.088837  -0.19803          -0.043478
#
#    Card slot_microsdhc  Card slot_microsdxc  Card slot_nano memory  \
# 0            -0.585339             0.897659              -0.125746
# 1             1.708411            -1.114008              -0.125746
# 2            -0.585339             0.897659              -0.125746
# 3            -0.585339             0.897659              -0.125746
# 4             1.708411            -1.114008              -0.125746
#
#    Card slot_no  Card slot_unspecified  Network_Support_000  \
# 0     -0.454535              -0.048622            -0.081533
# 1     -0.454535              -0.048622            -0.081533
# 2     -0.454535              -0.048622            -0.081533
# 3     -0.454535              -0.048622            -0.081533
# 4     -0.454535              -0.048622            -0.081533
#
#    Network_Support_010  Network_Support_100  Network_Support_110  \
# 0            -0.057557            -0.582434             0.806902
# 1            -0.057557             1.716933            -1.239308
# 2            -0.057557            -0.582434             0.806902
# 3            -0.057557            -0.582434             0.806902
# 4            -0.057557             1.716933            -1.239308
#
#    Network_Support_111
# 0            -0.388488
# 1            -0.388488
# 2            -0.388488
# 3            -0.388488
# 4            -0.388488

# %% [markdown]
# ### Models

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import label_binarize
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# Logistic Rgression

# %%
log_reg_params = {
    'C': np.logspace(-4, 4, 20),
    'solver': ['liblinear', 'lbfgs','saga'],
    'max_iter': [100, 1000, 2500, 5000]
}

log_reg = LogisticRegression(multi_class='multinomial')

log_reg_random = RandomizedSearchCV(log_reg, log_reg_params, n_iter=10, cv=5, random_state=42, scoring='precision_weighted')
log_reg_random.fit(X_train_smote, y_train_smote)
# Out:
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 20 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 20 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1212, in fit
#     multi_class = _check_multi_class(self.multi_class, solver, len(self.classes_))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py", line 99, in _check_multi_class
#     raise ValueError("Solver %s does not support a multinomial backend." % solver)
# ValueError: Solver liblinear does not support a multinomial backend.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan 0.9200343  0.91796171 0.92119068
#  0.9209695  0.90931589        nan 0.91998063]
#   warnings.warn(
# RandomizedSearchCV(cv=5,
#                    estimator=LogisticRegression(multi_class='multinomial'),
#                    param_distributions={'C': array([1.00000000e-04, 2.63665090e-04, 6.95192796e-04, 1.83298071e-03,
#        4.83293024e-03, 1.27427499e-02, 3.35981829e-02, 8.85866790e-02,
#        2.33572147e-01, 6.15848211e-01, 1.62377674e+00, 4.28133240e+00,
#        1.12883789e+01, 2.97635144e+01, 7.84759970e+01, 2.06913808e+02,
#        5.45559478e+02, 1.43844989e+03, 3.79269019e+03, 1.00000000e+04]),
#                                         'max_iter': [100, 1000, 2500, 5000],
#                                         'solver': ['liblinear', 'lbfgs',
#                                                    'saga']},
#                    random_state=42, scoring='precision_weighted')

# %%
log_reg_random.best_score_
# Out:
# 0.9211906828619968

# %%
log_reg_random.best_params_
# Out:
# {'solver': 'lbfgs', 'max_iter': 1000, 'C': 78.47599703514607}

# %%
pd.DataFrame(log_reg_random.cv_results_)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_solver  \
# 0       0.012283      0.003505         0.000000        0.000000    liblinear
# 1       0.008714      0.004954         0.000000        0.000000    liblinear
# 2       0.012797      0.006399         0.000000        0.000000    liblinear
# 3       0.132909      0.013140         0.011161        0.005134        lbfgs
# 4       1.267507      0.151340         0.015311        0.000918         saga
# 5       0.384783      0.113341         0.010560        0.008744        lbfgs
# 6       3.830158      0.263352         0.010373        0.005808         saga
# 7       0.346065      0.036917         0.012518        0.006259         saga
# 8       0.012630      0.004487         0.000000        0.000000    liblinear
# 9       6.458052      1.436192         0.011826        0.006974         saga
#
#   param_max_iter    param_C  \
# 0            100   0.000695
# 1           2500     0.0001
# 2           5000   0.088587
# 3            100   0.615848
# 4           2500   0.233572
# 5           1000  78.475997
# 6           1000    10000.0
# 7            100   0.088587
# 8           5000     0.0001
# 9           5000   4.281332
#
#                                               params  split0_test_score  \
# 0  {'solver': 'liblinear', 'max_iter': 100, 'C': ...                NaN
# 1  {'solver': 'liblinear', 'max_iter': 2500, 'C':...                NaN
# 2  {'solver': 'liblinear', 'max_iter': 5000, 'C':...                NaN
# 3  {'solver': 'lbfgs', 'max_iter': 100, 'C': 0.61...           0.904702
# 4  {'solver': 'saga', 'max_iter': 2500, 'C': 0.23...           0.900679
# 5  {'solver': 'lbfgs', 'max_iter': 1000, 'C': 78....           0.908128
# 6  {'solver': 'saga', 'max_iter': 1000, 'C': 1000...           0.906019
# 7  {'solver': 'saga', 'max_iter': 100, 'C': 0.088...           0.893955
# 8  {'solver': 'liblinear', 'max_iter': 5000, 'C':...                NaN
# 9  {'solver': 'saga', 'max_iter': 5000, 'C': 4.28...           0.902856
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0                NaN                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3           0.914538           0.930502           0.922275           0.928155
# 4           0.912680           0.927916           0.922332           0.926202
# 5           0.915392           0.929298           0.921175           0.931961
# 6           0.916681           0.929156           0.921762           0.931229
# 7           0.904654           0.921864           0.912415           0.913691
# 8                NaN                NaN                NaN                NaN
# 9           0.915453           0.929200           0.921767           0.930627
#
#    mean_test_score  std_test_score  rank_test_score
# 0              NaN             NaN                7
# 1              NaN             NaN                7
# 2              NaN             NaN                7
# 3         0.920034        0.009443                3
# 4         0.917962        0.010126                5
# 5         0.921191        0.008786                1
# 6         0.920970        0.009109                2
# 7         0.909316        0.009422                6
# 8              NaN             NaN                7
# 9         0.919981        0.010152                4

# %%
log_pred = log_reg_random.best_estimator_.predict(X_test_scaled)

# %%
from sklearn.metrics import classification_report

report = classification_report(y_test, log_pred)

print(report)
# Out:
#               precision    recall  f1-score   support
#
#      Android       0.99      0.81      0.89       491
#       Others       0.12      0.64      0.21        14
#      Windows       0.26      0.85      0.40        13
#          iOS       0.86      0.92      0.89        13
#
#     accuracy                           0.81       531
#    macro avg       0.56      0.81      0.60       531
# weighted avg       0.94      0.81      0.86       531

# %%
log_reg_random.best_estimator_.coef_
# Out:
# array([[-1.01961621e-01, -3.90179462e+00,  3.16006441e+00,
#         -1.40162981e-01,  1.45116887e+00,  1.35589248e+00,
#         -8.67753263e-02,  2.20145160e-01, -1.06647785e-01,
#         -2.46061182e-01,  4.84113282e+00, -2.34608961e+00,
#         -1.28307803e-01,  8.51126556e-02,  2.80419312e+00,
#         -2.80419312e+00,  3.17863672e+00,  3.72630665e+00,
#          1.04393437e+00, -2.12716698e-01,  7.91416683e-01,
#          8.47576445e+00,  8.98643345e+00,  2.83199679e+00,
#          4.46008699e+00,  1.06501471e+00],
#        [ 1.17694366e+00, -2.30532505e+00,  6.40012810e-01,
#         -2.27784776e+00,  1.45938553e-01,  1.46811585e+00,
#         -2.85552998e-01,  1.73066398e+00,  1.57534995e+00,
#         -8.18626590e-01,  5.75309853e+00, -1.81165278e+00,
#         -1.33829839e-01,  5.40494724e-01,  2.86638632e+00,
#         -2.86638632e+00,  1.47634402e+00,  2.66708996e+00,
#         -6.53067667e-01, -5.68290328e+00, -3.73226123e-02,
#          3.05908017e-01, -1.06909241e+00,  6.32825145e-01,
#         -2.43586841e+00, -1.53713305e+00],
#        [-3.93900303e+00, -1.70046596e+00,  2.86372245e-01,
#         -6.50434542e-01,  1.90672872e+00, -3.93077950e-01,
#         -9.87445108e-01,  8.66456038e-01,  3.00858040e-01,
#          3.96057102e+00, -9.99413997e-01,  5.15162615e+00,
#         -1.46324056e-01, -2.19773732e-03, -4.97099604e+00,
#          4.97099604e+00,  7.30381469e-01,  2.93590900e-01,
#         -4.23926430e-01, -5.02730780e-02, -7.77467417e-01,
#         -8.61775435e+00, -6.24315162e+00, -1.72208592e+00,
#         -7.16420441e+00,  1.30152301e-01],
#        [ 2.86402100e+00,  7.90758563e+00, -4.08644947e+00,
#          3.06844529e+00, -3.50383614e+00, -2.43093038e+00,
#          1.35977343e+00, -2.81726518e+00, -1.76956021e+00,
#         -2.89588324e+00, -9.59481735e+00, -9.93883760e-01,
#          4.08461698e-01, -6.23409642e-01, -6.99583395e-01,
#          6.99583395e-01, -5.38536220e+00, -6.68698752e+00,
#          3.30597275e-02,  5.94589305e+00,  2.33733462e-02,
#         -1.63918113e-01, -1.67418943e+00, -1.74273602e+00,
#          5.13998584e+00,  3.41966038e-01]])

# %%
log_reg_random.best_estimator_.classes_
# Out:
# array(['Android', 'Others', 'Windows', 'iOS'], dtype=object)

# %%
coefficients = log_reg_random.best_estimator_.coef_

n_classes = coefficients.shape[0]
n_features = coefficients.shape[1]
feature_names = X_train.columns
class_names = log_reg_random.best_estimator_.classes_

plt.figure(figsize=(15, n_classes * 5))

for class_idx in range(n_classes):
    plt.subplot(n_classes, 1, class_idx + 1)
    sorted_idx = np.argsort(coefficients[class_idx])
    
    plt.barh(range(n_features), coefficients[class_idx][sorted_idx], align='center')
    plt.yticks(range(n_features), feature_names[sorted_idx])
    plt.title(f'Class {class_names[class_idx]} Feature Importances (Coefficients)')
    plt.xlabel('Coefficient Value')
    plt.ylabel('Feature')

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import label_binarize

y_test_binarized = label_binarize(y_test, classes=np.unique(y_test))
y_pred_proba = log_reg_random.best_estimator_.predict_proba(X_test_scaled)

auc_score = roc_auc_score(y_test_binarized, y_pred_proba, multi_class='ovr')

print(f'Multi-class AUC: {auc_score}')
# Out:
# Multi-class AUC: 0.9094354696599356

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_test, log_pred)

disp = ConfusionMatrixDisplay(cm, display_labels=np.unique(y_test))

disp.plot()
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# SVM (linear, non-linear)

# %%
import sklearn
from sklearn.svm import SVC

svm_params = {
    'C': np.logspace(-4, 4, 20),
    'kernel': ['linear', 'rbf', 'poly'],
    'gamma': ['scale', 'auto'],
    'degree': [2, 3, 4]  #for 'poly' kernel
}

svm = SVC(decision_function_shape='ovo', probability=True) 

svm_random = RandomizedSearchCV(svm, svm_params, n_iter=10, cv=5, random_state=42, scoring='precision_weighted')
svm_random.fit(X_train_smote, y_train_smote)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=SVC(decision_function_shape='ovo',
#                                  probability=True),
#                    param_distributions={'C': array([1.00000000e-04, 2.63665090e-04, 6.95192796e-04, 1.83298071e-03,
#        4.83293024e-03, 1.27427499e-02, 3.35981829e-02, 8.85866790e-02,
#        2.33572147e-01, 6.15848211e-01, 1.62377674e+00, 4.28133240e+00,
#        1.12883789e+01, 2.97635144e+01, 7.84759970e+01, 2.06913808e+02,
#        5.45559478e+02, 1.43844989e+03, 3.79269019e+03, 1.00000000e+04]),
#                                         'degree': [2, 3, 4],
#                                         'gamma': ['scale', 'auto'],
#                                         'kernel': ['linear', 'rbf', 'poly']},
#                    random_state=42, scoring='precision_weighted')

# %%
svm_random.best_score_
# Out:
# 0.978601421115356

# %%
svm_random.best_estimator_
# Out:
# SVC(C=545.5594781168514, decision_function_shape='ovo', degree=4, kernel='poly',
#     probability=True)

# %%
pd.DataFrame(svm_random.cv_results_)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_kernel  \
# 0       0.873578      0.051272         0.052728        0.003151         poly
# 1       2.660962      0.061636         0.139670        0.008820       linear
# 2      28.598570      2.224472         0.037856        0.006078       linear
# 3       0.853033      0.060778         0.027027        0.007770         poly
# 4       5.739588      0.231726         0.180349        0.004815         poly
# 5       0.894910      0.100510         0.028221        0.008407         poly
# 6       4.917951      0.118156         0.181684        0.005739       linear
# 7       1.883209      0.067157         0.108008        0.005509       linear
# 8       0.926628      0.092259         0.052929        0.013143         poly
# 9       3.849349      0.154621         0.476550        0.044976          rbf
#
#   param_gamma param_degree     param_C  \
# 0       scale            3   11.288379
# 1       scale            3    0.000695
# 2        auto            4  206.913808
# 3       scale            4  545.559478
# 4       scale            2    0.001833
# 5       scale            2  206.913808
# 6        auto            4      0.0001
# 7        auto            2    0.001833
# 8       scale            4   29.763514
# 9        auto            4    0.033598
#
#                                               params  split0_test_score  \
# 0  {'kernel': 'poly', 'gamma': 'scale', 'degree':...           0.929705
# 1  {'kernel': 'linear', 'gamma': 'scale', 'degree...           0.837409
# 2  {'kernel': 'linear', 'gamma': 'auto', 'degree'...           0.923517
# 3  {'kernel': 'poly', 'gamma': 'scale', 'degree':...           0.958018
# 4  {'kernel': 'poly', 'gamma': 'scale', 'degree':...           0.619243
# 5  {'kernel': 'poly', 'gamma': 'scale', 'degree':...           0.952865
# 6  {'kernel': 'linear', 'gamma': 'auto', 'degree'...           0.736417
# 7  {'kernel': 'linear', 'gamma': 'auto', 'degree'...           0.844530
# 8  {'kernel': 'poly', 'gamma': 'scale', 'degree':...           0.941692
# 9  {'kernel': 'rbf', 'gamma': 'auto', 'degree': 4...           0.857163
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.944774           0.970079           0.961099           0.957697
# 1           0.843695           0.843586           0.844220           0.864547
# 2           0.939134           0.947972           0.937052           0.947268
# 3           0.978251           0.986180           0.987453           0.983105
# 4           0.633148           0.612777           0.597609           0.601620
# 5           0.977937           0.981920           0.987326           0.975036
# 6           0.741472           0.735566           0.741009           0.746835
# 7           0.851144           0.848442           0.854774           0.867082
# 8           0.953559           0.974570           0.968819           0.960287
# 9           0.865532           0.869534           0.866755           0.881931
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.952671        0.014065                4
# 1         0.846691        0.009271                8
# 2         0.938988        0.008859                5
# 3         0.978601        0.010769                1
# 4         0.612879        0.012738               10
# 5         0.975017        0.011819                2
# 6         0.740260        0.004051                9
# 7         0.853194        0.007710                7
# 8         0.959785        0.011546                3
# 9         0.868183        0.008017                6

# %%
svm_pred = svm_random.best_estimator_.predict(X_test_scaled)
report = classification_report(y_test, svm_pred)

print(report)
# Out:
#               precision    recall  f1-score   support
#
#      Android       0.98      0.95      0.96       491
#       Others       0.30      0.57      0.39        14
#      Windows       0.55      0.85      0.67        13
#          iOS       1.00      0.85      0.92        13
#
#     accuracy                           0.93       531
#    macro avg       0.71      0.80      0.73       531
# weighted avg       0.95      0.93      0.94       531

# %%
y_test_binarized = label_binarize(y_test, classes=np.unique(y_test))
y_pred_proba = svm_random.best_estimator_.predict_proba(X_test_scaled)

auc_score = roc_auc_score(y_test_binarized, y_pred_proba, multi_class='ovo')

print(f'Multi-class AUC: {auc_score}')
# Out:
# Multi-class AUC: 0.8969506078231757

# %%
cm = confusion_matrix(y_test, svm_pred)

disp = ConfusionMatrixDisplay(cm, display_labels=np.unique(y_test))

disp.plot()
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

ada = AdaBoostClassifier(estimator=DecisionTreeClassifier() )
ada_params = {
    'estimator__max_depth': [1, 2, 3, 4, 5, 6, 7, 8, 9],
    'n_estimators': [50, 100, 200, 300, 400],
    'learning_rate': [0.01, 0.1, 1, 1.5, 2, 10]
}

ada_random = RandomizedSearchCV(ada, ada_params, n_iter=15, cv=5, random_state=42, scoring='precision_weighted')
ada_random.fit(X_train_scaled, y_train)
# Out:
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# RandomizedSearchCV(cv=5,
#                    estimator=AdaBoostClassifier(estimator=DecisionTreeClassifier()),
#                    n_iter=15,
#                    param_distributions={'estimator__max_depth': [1, 2, 3, 4, 5,
#                                                                  6, 7, 8, 9],
#                                         'learning_rate': [0.01, 0.1, 1, 1.5, 2,
#                                                           10],
#                                         'n_estimators': [50, 100, 200, 300,
#                                                          400]},
#                    random_state=42, scoring='precision_weighted')

# %%
ada_random.best_score_ #oversampled
# Out:
# 0.9936629174005424

# %%
ada_random.best_score_
# Out:
# 0.9615473553298226

# %%
ada_random.best_estimator_.get_params #oversampled
# Out:
# <bound method BaseEstimator.get_params of AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=8),
#                    learning_rate=1, n_estimators=300)>

# %%
ada_random.best_estimator_.get_params
# Out:
# <bound method BaseEstimator.get_params of AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=8),
#                    learning_rate=1.5, n_estimators=200)>

# %%
pd.DataFrame(ada_random.cv_results_) #oversampled
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       9.466078      0.892324         0.131255        0.007375
# 1       8.421910      0.265319         0.078328        0.005070
# 2      23.598445      0.333866         0.139331        0.011581
# 3      14.727623      0.495725         0.117421        0.013217
# 4       3.595876      0.034760         0.033735        0.004282
# 5       0.956936      0.030359         0.033274        0.002278
# 6      10.869920      0.226173         0.126727        0.019990
# 7      12.742071      0.350630         0.106969        0.008030
# 8      17.127427      0.397430         0.113223        0.012391
# 9      17.070633      0.826621         0.109908        0.018271
#
#   param_n_estimators param_learning_rate param_estimator__max_depth  \
# 0                400                  10                          1
# 1                200                0.01                          3
# 2                300                   1                          8
# 3                300                  10                          4
# 4                 50                 0.1                          8
# 5                 50                  10                          1
# 6                400                0.01                          2
# 7                300                 0.1                          4
# 8                300                   1                          6
# 9                300                  10                          6
#
#                                               params  split0_test_score  \
# 0  {'n_estimators': 400, 'learning_rate': 10, 'es...           0.447781
# 1  {'n_estimators': 200, 'learning_rate': 0.01, '...           0.909537
# 2  {'n_estimators': 300, 'learning_rate': 1, 'est...           0.980988
# 3  {'n_estimators': 300, 'learning_rate': 10, 'es...           0.868868
# 4  {'n_estimators': 50, 'learning_rate': 0.1, 'es...           0.976371
# 5  {'n_estimators': 50, 'learning_rate': 10, 'est...           0.449718
# 6  {'n_estimators': 400, 'learning_rate': 0.01, '...           0.839084
# 7  {'n_estimators': 300, 'learning_rate': 0.1, 'e...           0.964033
# 8  {'n_estimators': 300, 'learning_rate': 1, 'est...           0.978609
# 9  {'n_estimators': 300, 'learning_rate': 10, 'es...           0.959451
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.484189           0.495235           0.488915           0.487715
# 1           0.871801           0.906399           0.856022           0.852973
# 2           0.996200           0.997462           0.996202           0.997462
# 3           0.950300           0.969526           0.891405           0.955542
# 4           0.989806           0.994924           0.991125           0.992983
# 5           0.484189           0.495356           0.489035           0.487715
# 6           0.834040           0.846567           0.831492           0.801410
# 7           0.968253           0.913126           0.974793           0.968348
# 8           0.994940           0.996835           0.997457           0.996198
# 9           0.957722           0.966064           0.974720           0.979733
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.480767        0.016875               10
# 1         0.879346        0.024248                7
# 2         0.993663        0.006362                1
# 3         0.927128        0.039528                6
# 4         0.989042        0.006567                3
# 5         0.481202        0.016151                9
# 6         0.830518        0.015437                8
# 7         0.957710        0.022556                5
# 8         0.992808        0.007148                2
# 9         0.967538        0.008535                4

# %%
pd.DataFrame(ada_random.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.264213      0.015513         0.014375        0.003168
# 1        0.794993      0.036048         0.019031        0.006123
# 2        2.560729      0.104009         0.059193        0.007975
# 3        1.841750      0.097664         0.038418        0.006413
# 4        1.153069      0.063737         0.019840        0.003531
# 5        1.780826      0.112671         0.037761        0.006635
# 6        4.235108      0.275194         0.056397        0.006926
# 7        0.236157      0.021159         0.008815        0.007089
# 8        2.889215      0.142127         0.050411        0.004411
# 9        2.757372      0.132795         0.045461        0.007498
# 10       3.244345      0.075078         0.055680        0.008840
# 11       3.598280      0.082192         0.048212        0.003890
# 12       2.267262      0.093071         0.036190        0.007718
# 13       1.292468      0.032133         0.034022        0.008737
# 14       0.493316      0.031451         0.009821        0.007819
#
#    param_n_estimators param_learning_rate param_estimator__max_depth  \
# 0                  50                0.01                          2
# 1                 100                  10                          4
# 2                 400                 1.5                          3
# 3                 200                 0.1                          5
# 4                 100                 1.5                          7
# 5                 200                 1.5                          5
# 6                 400                  10                          7
# 7                  50                 1.5                          2
# 8                 300                 0.1                          6
# 9                 200                 0.1                          9
# 10                300                0.01                          7
# 11                300                  10                          9
# 12                200                 1.5                          8
# 13                200                   2                          3
# 14                 50                 1.5                          6
#
#                                                params  split0_test_score  \
# 0   {'n_estimators': 50, 'learning_rate': 0.01, 'e...           0.898428
# 1   {'n_estimators': 100, 'learning_rate': 10, 'es...           0.947319
# 2   {'n_estimators': 400, 'learning_rate': 1.5, 'e...           0.947056
# 3   {'n_estimators': 200, 'learning_rate': 0.1, 'e...           0.958310
# 4   {'n_estimators': 100, 'learning_rate': 1.5, 'e...           0.972539
# 5   {'n_estimators': 200, 'learning_rate': 1.5, 'e...           0.970324
# 6   {'n_estimators': 400, 'learning_rate': 10, 'es...           0.972233
# 7   {'n_estimators': 50, 'learning_rate': 1.5, 'es...           0.905207
# 8   {'n_estimators': 300, 'learning_rate': 0.1, 'e...           0.965174
# 9   {'n_estimators': 200, 'learning_rate': 0.1, 'e...           0.961071
# 10  {'n_estimators': 300, 'learning_rate': 0.01, '...           0.953816
# 11  {'n_estimators': 300, 'learning_rate': 10, 'es...           0.933698
# 12  {'n_estimators': 200, 'learning_rate': 1.5, 'e...           0.971557
# 13  {'n_estimators': 200, 'learning_rate': 2, 'est...           0.950416
# 14  {'n_estimators': 50, 'learning_rate': 1.5, 'es...           0.972343
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.871405           0.886478           0.878351
# 1            0.920448           0.954645           0.933942
# 2            0.924995           0.952020           0.935297
# 3            0.935999           0.958369           0.939795
# 4            0.950074           0.968120           0.956293
# 5            0.954387           0.961572           0.951972
# 6            0.950273           0.956848           0.935736
# 7            0.890648           0.940234           0.895319
# 8            0.943192           0.956432           0.953451
# 9            0.950112           0.961048           0.941179
# 10           0.943672           0.958885           0.950675
# 11           0.929512           0.965093           0.950568
# 12           0.951169           0.970324           0.956293
# 13           0.938062           0.962473           0.937425
# 14           0.950509           0.963744           0.954127
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.910998         0.889132        0.014156               15
# 1            0.962543         0.943779        0.014992               12
# 2            0.943673         0.940608        0.009520               13
# 3            0.945630         0.947621        0.009274               10
# 4            0.956201         0.960645        0.008340                2
# 5            0.954019         0.958455        0.006765                4
# 6            0.962543         0.955527        0.012242                5
# 7            0.923307         0.910943        0.018438               14
# 8            0.950458         0.953741        0.007212                6
# 9            0.936803         0.950043        0.009966                8
# 10           0.959294         0.953268        0.005779                7
# 11           0.955706         0.946915        0.013406               11
# 12           0.958394         0.961547        0.008031                1
# 13           0.950877         0.947851        0.009317                9
# 14           0.956201         0.959385        0.007791                3

# %%
ada_pred = ada_random.best_estimator_.predict(X_test_scaled)
report = classification_report(y_test, ada_pred) #oversampled

print(report)
# Out:
#               precision    recall  f1-score   support
#
#      Android       0.97      1.00      0.98       491
#       Others       0.89      0.57      0.70        14
#      Windows       0.78      0.54      0.64        13
#          iOS       1.00      0.62      0.76        13
#
#     accuracy                           0.96       531
#    macro avg       0.91      0.68      0.77       531
# weighted avg       0.96      0.96      0.96       531

# %%
ada_pred = ada_random.best_estimator_.predict(X_test_scaled)
report = classification_report(y_test, ada_pred)

print(report)
# Out:
#               precision    recall  f1-score   support
#
#      Android       0.97      1.00      0.98       491
#       Others       1.00      0.50      0.67        14
#      Windows       0.78      0.54      0.64        13
#          iOS       1.00      0.77      0.87        13
#
#     accuracy                           0.97       531
#    macro avg       0.94      0.70      0.79       531
# weighted avg       0.97      0.97      0.96       531

# %%
indices = np.argsort(ada_random.best_estimator_.feature_importances_)[::-1]
sns.barplot(y=X_train_scaled.columns[indices], x=ada_random.best_estimator_.feature_importances_[indices])
# Out:
# <Axes: >

# %%
y_test_binarized = label_binarize(y_test, classes=np.unique(y_test))
y_pred_proba = ada_random.best_estimator_.predict_proba(X_test_scaled)

auc_score = roc_auc_score(y_test_binarized, y_pred_proba, multi_class='ovo')

print(f'Multi-class AUC: {auc_score}')
# Out:
# Multi-class AUC: 0.9621565454293929

# %%
cm = confusion_matrix(y_test, ada_pred) #oversampled

disp = ConfusionMatrixDisplay(cm, display_labels=np.unique(y_test) )

disp.plot()
plt.title('Confusion Matrix')
plt.show()

# %%
cm = confusion_matrix(y_test, ada_pred)

disp = ConfusionMatrixDisplay(cm, display_labels=np.unique(y_test) )

disp.plot()
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ### PART 2

# %%
data.groupby('OS')['battery_capacity'].describe()
# Out:
#           count         mean          std     min     25%     50%     75%  \
# OS
# Android  2449.0  3418.541854  1544.056445   200.0  2100.0  3075.0  4500.0
# Others     72.0  2639.305556  2007.543749    50.0  1200.0  1475.0  4325.0
# Windows    65.0  1771.230769   490.511556  1230.0  1430.0  1650.0  2000.0
# iOS        65.0  4578.876923  3001.951014   307.0  2438.0  3274.0  6930.0
#
#              max
# OS
# Android  11200.0
# Others    8300.0
# Windows   3400.0
# iOS      11560.0

# %%
data['battery_capacity'].describe()
# Out:
# count     2651.000000
# mean      3385.437948
# std       1627.512406
# min         50.000000
# 25%       2070.000000
# 50%       3000.000000
# 75%       4500.000000
# max      11560.000000
# Name: battery_capacity, dtype: float64

# %%
data['battery_cat'] = ['1' if x <= 2070 else '2' if x > 2070 and x <= 4500 else '3' for x in data.battery_capacity]

# %%
sns.countplot(data=data, x='battery_cat', hue='OS')
# Out:
# <Axes: xlabel='battery_cat', ylabel='count'>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2651 entries, 0 to 4678
# Data columns (total 40 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              2651 non-null   object
#  1   brand             2651 non-null   object
#  2   2G                2651 non-null   bool
#  3   3G                2651 non-null   bool
#  4   4G                2651 non-null   bool
#  5   5G                2651 non-null   bool
#  6   Announced         2651 non-null   float64
#  7   Status            2651 non-null   object
#  8   Weight            2651 non-null   float64
#  9   Length            2651 non-null   float64
#  10  Width             2651 non-null   object
#  11  Diameter          2651 non-null   object
#  12  SIM               2651 non-null   object
#  13  Display Type      2651 non-null   object
#  14  Display Size      2651 non-null   float64
#  15  ppi               2651 non-null   float64
#  16  body ratio        2651 non-null   float64
#  17  OS                2651 non-null   object
#  18  battery_capacity  2651 non-null   float64
#  19  Price             2651 non-null   float64
#  20  CPU               2372 non-null   float64
#  21  ratio             2651 non-null   object
#  22  pixel             2651 non-null   float64
#  23  WLAN              2650 non-null   object
#  24  Colors            2650 non-null   object
#  25  Sensors           2632 non-null   object
#  26  Bluetooth         2651 non-null   object
#  27  GPU               2427 non-null   object
#  28  Loudspeaker       2651 non-null   bool
#  29  3.5mm jack        2651 non-null   bool
#  30  Chipset           2394 non-null   object
#  31  Network           2651 non-null   object
#  32  Internal          2651 non-null   object
#  33  Card slot         2651 non-null   object
#  34  RAM               2651 non-null   float64
#  35  Storage           2651 non-null   float64
#  36  n_colors          2651 non-null   float64
#  37  Version           2649 non-null   object
#  38  Network_Support   2651 non-null   object
#  39  battery_cat       2651 non-null   object
# dtypes: bool(6), float64(13), object(21)
# memory usage: 740.4+ KB

# %%
feature_set = data.columns.drop(labels=['name','brand', '2G', '3G', '4G', '5G', 'OS', 'Display Type', '2G','Width', 'Diameter','CPU','ratio',
                                        'WLAN', 'Colors', 'Sensors', 'Bluetooth', 'GPU', 'Chipset', 'Network', 'Internal','Version','pixel', 
                                        'battery_capacity'])

# %%
categorical_cols_to_dummify = ['Status', 'SIM', 'Card slot', 'Network_Support', 'battery_cat']

cleaned_data = data[feature_set]
# cleaned_data.loc[cleaned_data.Status == 'Coming','Status'] = 'Available'
dummies = pd.get_dummies(cleaned_data[categorical_cols_to_dummify])
cleaned_data = pd.concat([cleaned_data, dummies], axis=1)
cleaned_data.drop(categorical_cols_to_dummify, inplace = True, axis=1)

cleaned_data['3.5mm jack'] = cleaned_data['3.5mm jack'].astype('int32')
cleaned_data['Loudspeaker'] = cleaned_data['Loudspeaker'].astype('int32')

# %%
cleaned_data.head()
# Out:
#    Announced  Weight  Length  Display Size    ppi  body ratio  Price  \
# 0     2022.0   172.0   146.7          5.50  293.0        74.0  100.0
# 1     2021.0   190.0   156.4          6.10  282.0        78.1  110.0
# 2     2021.0   134.0   137.6          5.00  215.0        71.4   60.0
# 3     2021.0   194.0   165.6          6.52  269.0        82.0  330.0
# 4     2021.0   190.0   165.6          6.52  269.0        82.0  130.0
#
#    Loudspeaker  3.5mm jack  RAM  Storage  n_colors  Status_Available  \
# 0            1           1  2.0     32.0       2.0              True
# 1            1           1  2.0     32.0       2.0              True
# 2            1           1  1.0      8.0       2.0              True
# 3            1           1  4.0     64.0       2.0              True
# 4            1           1  3.0     32.0       2.0              True
#
#    Status_Discontinued  SIM_Micro-SIM  SIM_Mini-SIM  SIM_Nano-SIM  SIM_eSIM  \
# 0                False          False         False          True     False
# 1                False          False         False          True     False
# 2                False          False         False          True     False
# 3                False          False         False          True     False
# 4                False          False         False          True     False
#
#    Card slot_microsd  Card slot_microsdhc  Card slot_microsdxc  \
# 0              False                False                 True
# 1              False                False                 True
# 2              False                 True                False
# 3              False                False                 True
# 4              False                False                 True
#
#    Card slot_nano memory  Card slot_no  Card slot_unspecified  \
# 0                  False         False                  False
# 1                  False         False                  False
# 2                  False         False                  False
# 3                  False         False                  False
# 4                  False         False                  False
#
#    Network_Support_000  Network_Support_010  Network_Support_100  \
# 0                False                False                False
# 1                False                False                False
# 2                False                False                False
# 3                False                False                False
# 4                False                False                False
#
#    Network_Support_110  Network_Support_111  battery_cat_1  battery_cat_2  \
# 0                 True                False          False           True
# 1                 True                False          False           True
# 2                 True                False           True          False
# 3                 True                False          False           True
# 4                 True                False          False           True
#
#    battery_cat_3
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False

# %%
X = cleaned_data
y = data['OS']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

scaler = StandardScaler()
X_train_scaled = pd.DataFrame(scaler.fit_transform(X_train), columns = X_train.columns)
X_test_scaled = pd.DataFrame(scaler.transform(X_test), columns= X_test.columns)

# %%
ada2 = AdaBoostClassifier(estimator=DecisionTreeClassifier() )
ada_params = {
    'estimator__max_depth': [1, 2, 3, 4, 5, 6, 7, 8, 9],
    'n_estimators': [50, 100, 200, 300, 400],
    'learning_rate': [0.01, 0.1, 1, 1.1,1.2,1.3, 1.5, 2, 10]
}

ada_random2 = RandomizedSearchCV(ada, ada_params, n_iter=15, cv=5, random_state=42, scoring='precision_weighted')
ada_random2.fit(X_train_scaled, y_train)
# Out:
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Snapp\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# RandomizedSearchCV(cv=5,
#                    estimator=AdaBoostClassifier(estimator=DecisionTreeClassifier()),
#                    n_iter=15,
#                    param_distributions={'estimator__max_depth': [1, 2, 3, 4, 5,
#                                                                  6, 7, 8, 9],
#                                         'learning_rate': [0.01, 0.1, 1, 1.1,
#                                                           1.2, 1.3, 1.5, 2,
#                                                           10],
#                                         'n_estimators': [50, 100, 200, 300,
#                                                          400]},
#                    random_state=42, scoring='precision_weighted')

# %%
ada_pred2 = ada_random2.best_estimator_.predict(X_test_scaled)
report = classification_report(y_test, ada_pred2)

print(report)
# Out:
#               precision    recall  f1-score   support
#
#      Android       0.97      1.00      0.98       491
#       Others       1.00      0.50      0.67        14
#      Windows       0.78      0.54      0.64        13
#          iOS       1.00      0.69      0.82        13
#
#     accuracy                           0.97       531
#    macro avg       0.94      0.68      0.78       531
# weighted avg       0.97      0.97      0.96       531

# %%
ada_pred2 = ada_random2.best_estimator_.predict(X_test_scaled)
report = classification_report(y_test, ada_pred2)

print(report)   #median
# Out:
#               precision    recall  f1-score   support
#
#      Android       0.96      1.00      0.98       491
#       Others       1.00      0.57      0.73        14
#      Windows       0.75      0.46      0.57        13
#          iOS       1.00      0.54      0.70        13
#
#     accuracy                           0.96       531
#    macro avg       0.93      0.64      0.74       531
# weighted avg       0.96      0.96      0.96       531

# %%
cm2 = confusion_matrix(y_test, ada_pred2)

disp = ConfusionMatrixDisplay(cm2, display_labels=np.unique(y_test) )

disp.plot()
plt.title('Confusion Matrix')
plt.show()
